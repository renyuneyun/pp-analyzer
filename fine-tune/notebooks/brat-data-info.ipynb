# %%
# %reload_ext autoreload
# %autoreload 2

from pprint import pprint
import csv
from copy import deepcopy
import json
import pathlib
from pathlib import Path
from openai import OpenAI
from dotenv import load_dotenv
import src.annotation_utils as a_utils
import src.llm_utils as llm_utils
import os

load_dotenv()

BRAT_DATA_PATH = os.environ['BRAT_DATA_PATH']
DATA_DEF_FILE = os.environ['DATA_CATEGORY_DEFINITION']

# %% [markdown]
# ## Load brat dataset

# %%
import dataclasses

from pybrat.parser import BratParser, Entity, Event, Example, Relation

# Initialize a parser.
brat = BratParser(error="ignore")
# brat = BratParser()
annotations = brat.parse(BRAT_DATA_PATH)

# %%
'''
Test the loaded annotation
'''

[e for x in annotations for e in x.entities]
# flag = False
for x in annotations:
    # for e in [n for l in [x.entities, x.relations, x.events] for n in l]:
    #     if e.references:
    #         print(e)
    # # print(x.text)
    pprint(x.entities)
    # pprint(x.relations)
    # print(x.events)
    # if flag: break
    # for e in x.events:
    #     # pprint(e)
    #     # if flag: break
    #     for e2 in x.events:
    #         if e == e2: continue
    #         if e.trigger.spans[0] == e2.trigger.spans[0]:
    #             # pprint(x.text)
    #             pprint([e.type, e2.type])
    #             # flag = True
    #             # break
# assert all(isinstance(e, Relation) for x in annotations for e in x.relations)
# assert all(isinstance(e, Event) for x in annotations for e in x.events)
# Out:
# []
# []
# [Entity(mention='you visit or access our Services',
#         type='Condition',
#         spans=[Span(start=40, end=72)],
#         references=[],
#         id='T1'),
#  Entity(mention='you',
#         type='User',
#         spans=[Span(start=40, end=43)],
#         references=[],
#         id='T2'),
#  Entity(mention='our',
#         type='First-party-entity',
#         spans=[Span(start=60, end=63)],
#         references=[],
#         id='T3'),
#  Entity(mention='use',
#         type='collection-use',
#         spans=[Span(start=119, end=122)],
#         references=[],
#         id='T4'),
#  Entity(mention='automatically collect information',
#         type='RecordManagement',
#         spans=[Span(start=292, end=325)],
#         references=[],
#         id='T14'),
#  Entity(mention='online behavior',
#         type='BrowsingBehavior',
#         spans=[Span(start=345, end=360)],
#         references=[],
#         id='T16'),
#  Entity(mention='device',
#         type='DeviceBased',
#         spans=[Span(start=378, end=384)],
#         references=[],
#         id='T17'),
#  Entity(mention='enhance your navigation on our Services',
#         type='OptimisationForConsumer',
#         spans=[Span(start=475, end=514)],
#         references=[],
#         id='T18'),
#  Entity(mention="improve our Services' performance",
#         type='ServiceOptimisation',
#         spans=[Span(start=516, end=549)],
#         references=[],
#         id='T19'),
#  Entity(mention='customize your experience on our Services',
#         type='ServicePersonalisation',
#         spans=[Span(start=554, end=595)],
#         references=[],
#         id='T20'),
#  Entity(mention='We',
#         type='First-party-entity',
#         spans=[Span(start=597, end=599)],
#         references=[],
#         id='T13'),
#  Entity(mention='use',
#         type='collection-use',
#         spans=[Span(start=605, end=608)],
#         references=[],
#         id='T15'),
#  Entity(mention='information',
#         type='Data-general',
#         spans=[Span(start=614, end=625)],
#         references=[],
#         id='T21'),
#  Entity(mention='collect statistics about the usage of our Services',
#         type='ServiceUsageAnalytics',
#         spans=[Span(start=629, end=679)],
#         references=[],
#         id='T22'),
#  Entity(mention='perform analytics',
#         type='ServiceUsageAnalytics',
#         spans=[Span(start=681, end=698)],
#         references=[],
#         id='T23'),
#  Entity(mention='deliver content which is tailored to your interests',
#         type='DirectMarketing',
#         spans=[Span(start=700, end=751)],
#         references=[],
#         id='T24'),
#  Entity(mention='administer services',
#         type='ServiceProvision',
#         spans=[Span(start=756, end=775)],
#         references=[],
#         id='T25'),
#  Entity(mention='We',
#         type='First-party-entity',
#         spans=[Span(start=839, end=841)],
#         references=[],
#         id='T26'),
#  Entity(mention='third parties',
#         type='Third-party-entity',
#         spans=[Span(start=853, end=866)],
#         references=[],
#         id='T27'),
#  Entity(mention='collect',
#         type='third-party-sharing-disclosure',
#         spans=[Span(start=870, end=877)],
#         references=[],
#         id='T28'),
#  Entity(mention='information',
#         type='Data-general',
#         spans=[Span(start=878, end=889)],
#         references=[],
#         id='T29'),
#  Entity(mention='you',
#         type='User',
#         spans=[Span(start=896, end=899)],
#         references=[],
#         id='T30'),
#  Entity(mention='authorize',
#         type='third-party-sharing-disclosure',
#         spans=[Span(start=128, end=137)],
#         references=[],
#         id='T32'),
#  Entity(mention='third parties',
#         type='Third-party-entity',
#         spans=[Span(start=138, end=151)],
#         references=[],
#         id='T33'),
#  Entity(mention='Users',
#         type='User',
#         spans=[Span(start=783, end=788)],
#         references=[],
#         id='T34')]
# []
# [Entity(mention='you have registered with an account through our Services',
#         type='Condition',
#         spans=[Span(start=38, end=94)],
#         references=[],
#         id='T1'),
#  Entity(mention='Company',
#         type='First-party-entity',
#         spans=[Span(start=100, end=107)],
#         references=[],
#         id='T2'),
#  Entity(mention='retain',
#         type='data-storage-retention-deletion',
#         spans=[Span(start=113, end=119)],
#         references=[],
#         id='T3'),
#  Entity(mention='Personal Information',
#         type='Data-general',
#         spans=[Span(start=125, end=145)],
#         references=[],
#         id='T5'),
#  Entity(mention='the period your account is active',
#         type='retention-period',
#         spans=[Span(start=153, end=186)],
#         references=[],
#         id='T6'),
#  Entity(mention='Company',
#         type='First-party-entity',
#         spans=[Span(start=205, end=212)],
#         references=[],
#         id='T7'),
#  Entity(mention='retain',
#         type='data-storage-retention-deletion',
#         spans=[Span(start=218, end=224)],
#         references=[],
#         id='T8'),
#  Entity(mention='your',
#         type='User',
#         spans=[Span(start=225, end=229)],
#         references=[],
#         id='T9'),
#  Entity(mention='Personal Data',
#         type='Data-general',
#         spans=[Span(start=230, end=243)],
#         references=[],
#         id='T10'),
#  Entity(mention='additional periods',
#         type='retention-period',
#         spans=[Span(start=248, end=266)],
#         references=[],
#         id='T11'),
#  Entity(mention='meet its legal obligations under applicable laws or '
#                 'regulations, such as the applicable gambling regulations, '
#                 'Know-Your-Customer and Anti-Money Laundering regulations',
#         type='LegalCompliance',
#         spans=[Span(start=293, end=459)],
#         references=[],
#         id='T12'),
#  Entity(mention='Company',
#         type='First-party-entity',
#         spans=[Span(start=478, end=485)],
#         references=[],
#         id='T13'),
#  Entity(mention='retain',
#         type='data-storage-retention-deletion',
#         spans=[Span(start=490, end=496)],
#         references=[],
#         id='T14'),
#  Entity(mention='your',
#         type='User',
#         spans=[Span(start=497, end=501)],
#         references=[],
#         id='T15'),
#  Entity(mention='Personal Information',
#         type='Data-general',
#         spans=[Span(start=502, end=522)],
#         references=[],
#         id='T16'),
#  Entity(mention='longer periods',
#         type='retention-period',
#         spans=[Span(start=527, end=541)],
#         references=[],
#         id='T17'),
#  Entity(mention="retaining such information is necessary for the Company's "
#                 'legitimate interests',
#         type='Condition',
#         spans=[Span(start=557, end=635)],
#         references=[],
#         id='T18'),
#  Entity(mention='you',
#         type='User',
#         spans=[Span(start=38, end=41)],
#         references=[],
#         id='T19'),
#  Entity(mention='fraud prevention',
#         type='FraudPreventionAndDetection',
#         spans=[Span(start=645, end=661)],
#         references=[],
#         id='T4'),
#  Entity(mention='record keeping',
#         type='RecordManagement',
#         spans=[Span(start=666, end=680)],
#         references=[],
#         id='T20'),
#  Entity(mention="the Company's legitimate interests",
#         type='Purpose-general',
#         spans=[Span(start=601, end=635)],
#         references=[],
#         id='T21')]
# []
# [Entity(mention='appropriate physical and technological safeguards',
#         type='general-safeguard-method',
#         spans=[Span(start=161, end=210)],
#         references=[],
#         id='T1'),
#  Entity(mention='safeguards',
#         type='data-security-protection',
#         spans=[Span(start=200, end=210)],
#         references=[],
#         id='T5'),
#  Entity(mention='We',
#         type='First-party-entity',
#         spans=[Span(start=140, end=142)],
#         references=[],
#         id='T6'),
#  Entity(mention='information',
#         type='Data-general',
#         spans=[Span(start=300, end=311)],
#         references=[],
#         id='T7'),
#  Entity(mention='employ',
#         type='data-security-protection',
#         spans=[Span(start=427, end=433)],
#         references=[],
#         id='T8'),
#  Entity(mention='industry standard procedures and controls',
#         type='general-safeguard-method',
#         spans=[Span(start=434, end=475)],
#         references=[],
#         id='T9'),
#  Entity(mention='We',
#         type='First-party-entity',
#         spans=[Span(start=424, end=426)],
#         references=[],
#         id='T11'),
#  Entity(mention='information',
#         type='Data-general',
#         spans=[Span(start=511, end=522)],
#         references=[],
#         id='T12'),
#  Entity(mention='Secure network topology',
#         type='Access-limitation',
#         spans=[Span(start=533, end=556)],
#         references=[],
#         id='T13'),
#  Entity(mention='intrusion prevention',
#         type='Access-limitation',
#         spans=[Span(start=573, end=593)],
#         references=[],
#         id='T14'),
#  Entity(mention='Firewall systems',
#         type='Access-limitation',
#         spans=[Span(start=598, end=614)],
#         references=[],
#         id='T15'),
#  Entity(mention='Encrypted communication',
#         type='encryptions',
#         spans=[Span(start=616, end=639)],
#         references=[],
#         id='T16'),
#  Entity(mention='Authentication',
#         type='user-authentication',
#         spans=[Span(start=641, end=655)],
#         references=[],
#         id='T17'),
#  Entity(mention='External and Internal audit tests',
#         type='Protection-other',
#         spans=[Span(start=676, end=709)],
#         references=[],
#         id='T18'),
#  Entity(mention='security',
#         type='data-security-protection',
#         spans=[Span(start=93, end=101)],
#         references=[],
#         id='T19'),
#  Entity(mention='information',
#         type='Data-general',
#         spans=[Span(start=127, end=138)],
#         references=[],
#         id='T20'),
#  Entity(mention='We',
#         type='First-party-entity',
#         spans=[Span(start=38, end=40)],
#         references=[],
#         id='T21'),
#  Entity(mention='your',
#         type='User',
#         spans=[Span(start=122, end=126)],
#         references=[],
#         id='T22'),
#  Entity(mention='unauthorized access',
#         type='security-threat',
#         spans=[Span(start=227, end=246)],
#         references=[],
#         id='T23'),
#  Entity(mention='users',
#         type='User',
#         spans=[Span(start=504, end=509)],
#         references=[],
#         id='T2'),
#  Entity(mention='Access Control',
#         type='Access-limitation',
#         spans=[Span(start=660, end=674)],
#         references=[],
#         id='T3'),
#  Entity(mention='we',
#         type='First-party-entity',
#         spans=[Span(start=725, end=727)],
#         references=[],
#         id='T4'),
#  Entity(mention='reasonable steps',
#         type='general-safeguard-method',
#         spans=[Span(start=733, end=749)],
#         references=[],
#         id='T10'),
#  Entity(mention='safeguard',
#         type='data-security-protection',
#         spans=[Span(start=753, end=762)],
#         references=[],
#         id='T24'),
#  Entity(mention='information',
#         type='Data-general',
#         spans=[Span(start=763, end=774)],
#         references=[],
#         id='T25'),
#  Entity(mention='we',
#         type='First-party-entity',
#         spans=[Span(start=879, end=881)],
#         references=[],
#         id='T27'),
#  Entity(mention='prevent',
#         type='data-security-protection',
#         spans=[Span(start=944, end=951)],
#         references=[],
#         id='T28'),
#  Entity(mention='such access',
#         type='Access-limitation',
#         spans=[Span(start=952, end=963)],
#         references=[],
#         id='T29'),
#  Entity(mention='no',
#         type='Negation',
#         spans=[Span(start=887, end=889)],
#         references=[],
#         id='T30')]
# []
# []
# [Entity(mention='We',
#         type='First-party-entity',
#         spans=[Span(start=30, end=32)],
#         references=[],
#         id='T1'),
#  Entity(mention='collect',
#         type='collection-use',
#         spans=[Span(start=33, end=40)],
#         references=[],
#         id='T2'),
#  Entity(mention='information',
#         type='Data-general',
#         spans=[Span(start=54, end=65)],
#         references=[],
#         id='T3'),
#  Entity(mention='Users',
#         type='User',
#         spans=[Span(start=75, end=80)],
#         references=[],
#         id='T4')]
# [Entity(mention='name',
#         type='Name',
#         spans=[Span(start=1155, end=1159)],
#         references=[],
#         id='T8'),
#  Entity(mention='birthdate',
#         type='BirthDate',
#         spans=[Span(start=1161, end=1170)],
#         references=[],
#         id='T9'),
#  Entity(mention='profile picture',
#         type='Picture',
#         spans=[Span(start=1172, end=1187)],
#         references=[],
#         id='T10'),
#  Entity(mention="friends' list",
#         type='Friend',
#         spans=[Span(start=1192, end=1205)],
#         references=[],
#         id='T11'),
#  Entity(mention='the person accept your invitation',
#         type='Condition',
#         spans=[Span(start=1402, end=1435)],
#         references=[],
#         id='T12'),
#  Entity(mention='we',
#         type='First-party-entity',
#         spans=[Span(start=1437, end=1439)],
#         references=[],
#         id='T13'),
#  Entity(mention='obtain',
#         type='collection-use',
#         spans=[Span(start=1444, end=1450)],
#         references=[],
#         id='T14'),
#  Entity(mention='Personal Information',
#         type='Data-general',
#         spans=[Span(start=1451, end=1471)],
#         references=[],
#         id='T15'),
#  Entity(mention='him/her',
#         type='Third-party-entity',
#         spans=[Span(start=1477, end=1484)],
#         references=[],
#         id='T16'),
#  Entity(mention='name',
#         type='Name',
#         spans=[Span(start=1494, end=1498)],
#         references=[],
#         id='T17'),
#  Entity(mention='email address',
#         type='EmailAddress',
#         spans=[Span(start=1500, end=1513)],
#         references=[],
#         id='T18'),
#  Entity(mention='phone number',
#         type='TelephoneNumber',
#         spans=[Span(start=1515, end=1527)],
#         references=[],
#         id='T19'),
#  Entity(mention='date of birth',
#         type='BirthDate',
#         spans=[Span(start=1532, end=1545)],
#         references=[],
#         id='T20'),
#  Entity(mention='purposes set out herein',
#         type='Purpose-general',
#         spans=[Span(start=1592, end=1615)],
#         references=[],
#         id='T21'),
#  Entity(mention='We',
#         type='First-party-entity',
#         spans=[Span(start=1547, end=1549)],
#         references=[],
#         id='T22'),
#  Entity(mention='use',
#         type='collection-use',
#         spans=[Span(start=1555, end=1558)],
#         references=[],
#         id='T23'),
#  Entity(mention='Personal Information',
#         type='Data-general',
#         spans=[Span(start=1563, end=1583)],
#         references=[],
#         id='T24'),
#  Entity(mention='We',
#         type='First-party-entity',
#         spans=[Span(start=1747, end=1749)],
#         references=[],
#         id='T25'),
#  Entity(mention='collect',
#         type='collection-use',
#         spans=[Span(start=1750, end=1757)],
#         references=[],
#         id='T26'),
#  Entity(mention='Personal Information',
#         type='Data-general',
#         spans=[Span(start=1758, end=1778)],
#         references=[],
#         id='T27'),
#  Entity(mention='third party service providers',
#         type='Third-party-entity',
#         spans=[Span(start=1784, end=1813)],
#         references=[],
#         id='T28'),
#  Entity(mention='information about your credit history',
#         type='CreditRecord',
#         spans=[Span(start=1823, end=1860)],
#         references=[],
#         id='T29'),
#  Entity(mention='credit agencies',
#         type='Third-party-entity',
#         spans=[Span(start=1866, end=1881)],
#         references=[],
#         id='T30'),
#  Entity(mention='other financial information',
#         type='Financial',
#         spans=[Span(start=1886, end=1913)],
#         references=[],
#         id='T31'),
#  Entity(mention='is relevant to the provision of the Services',
#         type='Condition',
#         spans=[Span(start=1920, end=1964)],
#         references=[],
#         id='T32'),
#  Entity(mention='information',
#         type='Data-general',
#         spans=[Span(start=1977, end=1988)],
#         references=[],
#         id='T33'),
#  Entity(mention='verify your identity',
#         type='IdentityVerification',
#         spans=[Span(start=2019, end=2039)],
#         references=[],
#         id='T34'),
#  Entity(mention='prevent fraudulent or illegal activity',
#         type='FraudPreventionAndDetection',
#         spans=[Span(start=2044, end=2082)],
#         references=[],
#         id='T35'),
#  Entity(mention='We',
#         type='First-party-entity',
#         spans=[Span(start=386, end=388)],
#         references=[],
#         id='T36'),
#  Entity(mention='collect',
#         type='collection-use',
#         spans=[Span(start=394, end=401)],
#         references=[],
#         id='T37'),
#  Entity(mention='information',
#         type='Data-general',
#         spans=[Span(start=402, end=413)],
#         references=[],
#         id='T38'),
#  Entity(mention='you',
#         type='User',
#         spans=[Span(start=420, end=423)],
#         references=[],
#         id='T39'),
#  Entity(mention='you provide us voluntarily',
#         type='Opt-in',
#         spans=[Span(start=420, end=446)],
#         references=[],
#         id='T40'),
#  Entity(mention='we',
#         type='First-party-entity',
#         spans=[Span(start=678, end=680)],
#         references=[],
#         id='T41'),
#  Entity(mention='collect',
#         type='collection-use',
#         spans=[Span(start=681, end=688)],
#         references=[],
#         id='T42'),
#  Entity(mention='information with regard to your device, software or hardware',
#         type='DeviceBased',
#         spans=[Span(start=730, end=790)],
#         references=[],
#         id='T43'),
#  Entity(mention="device's unique identifiers",
#         type='DeviceIdentifier',
#         spans=[Span(start=823, end=850)],
#         references=[],
#         id='T44'),
#  Entity(mention='browser fingerprinting',
#         type='BrowserFingerprint',
#         spans=[Span(start=883, end=905)],
#         references=[],
#         id='T45'),
#  Entity(mention='IP address',
#         type='IPAddress',
#         spans=[Span(start=907, end=917)],
#         references=[],
#         id='T46'),
#  Entity(mention='geo-location data',
#         type='Location',
#         spans=[Span(start=922, end=939)],
#         references=[],
#         id='T47'),
#  Entity(mention='you voluntarily decide to register through your social '
#                 'network account',
#         type='Opt-in',
#         spans=[Span(start=963, end=1033)],
#         references=[],
#         id='T48'),
#  Entity(mention='we',
#         type='First-party-entity',
#         spans=[Span(start=1067, end=1069)],
#         references=[],
#         id='T49'),
#  Entity(mention='access',
#         type='collection-use',
#         spans=[Span(start=1080, end=1086)],
#         references=[],
#         id='T50'),
#  Entity(mention='basic information from your social network account',
#         type='SocialNetwork',
#         spans=[Span(start=1090, end=1140)],
#         references=[],
#         id='T51'),
#  Entity(mention='you',
#         type='User',
#         spans=[Span(start=260, end=263)],
#         references=[],
#         id='T3'),
#  Entity(mention='contact details',
#         type='Contact',
#         spans=[Span(start=304, end=319)],
#         references=[],
#         id='T4'),
#  Entity(mention='provide',
#         type='collection-use',
#         spans=[Span(start=280, end=287)],
#         references=[],
#         id='T5'),
#  Entity(mention='us',
#         type='First-party-entity',
#         spans=[Span(start=288, end=290)],
#         references=[],
#         id='T6'),
#  Entity(mention='full name',
#         type='Name',
#         spans=[Span(start=334, end=343)],
#         references=[],
#         id='T7'),
#  Entity(mention='email address',
#         type='EmailAddress',
#         spans=[Span(start=348, end=361)],
#         references=[],
#         id='T53'),
#  Entity(mention='connection details',
#         type='Data-general',
#         spans=[Span(start=707, end=725)],
#         references=[],
#         id='T54'),
#  Entity(mention='UDID',
#         type='UID',
#         spans=[Span(start=857, end=861)],
#         references=[],
#         id='T55'),
#  Entity(mention='IMEI',
#         type='DeviceIdentifier',
#         spans=[Span(start=863, end=867)],
#         references=[],
#         id='T56'),
#  Entity(mention='MAC address',
#         type='MACAddress',
#         spans=[Span(start=869, end=880)],
#         references=[],
#         id='T57'),
#  Entity(mention='you',
#         type='User',
#         spans=[Span(start=963, end=966)],
#         references=[],
#         id='T58'),
#  Entity(mention='information you made publicly available on such account',
#         type='PubliclyAvailableSocialMedia',
#         spans=[Span(start=1218, end=1273)],
#         references=[],
#         id='T52'),
#  Entity(mention='your',
#         type='User',
#         spans=[Span(start=1420, end=1424)],
#         references=[],
#         id='T59'),
#  Entity(mention='disclose',
#         type='third-party-sharing-disclosure',
#         spans=[Span(start=1620, end=1628)],
#         references=[],
#         id='T60'),
#  Entity(mention='information',
#         type='Data-general',
#         spans=[Span(start=1634, end=1645)],
#         references=[],
#         id='T61'),
#  Entity(mention='third parties',
#         type='Third-party-entity',
#         spans=[Span(start=1654, end=1667)],
#         references=[],
#         id='T62'),
#  Entity(mention='your',
#         type='User',
#         spans=[Span(start=2026, end=2030)],
#         references=[],
#         id='T63'),
#  Entity(mention='Personal Information',
#         type='Data-general',
#         spans=[Span(start=168, end=188)],
#         references=[],
#         id='T1'),
#  Entity(mention='gathered',
#         type='collection-use',
#         spans=[Span(start=204, end=212)],
#         references=[],
#         id='T2'),
#  Entity(mention='Contact details:',
#         type='Contact',
#         spans=[Span(start=243, end=259)],
#         references=[],
#         id='T65'),
#  Entity(mention='Voluntary information',
#         type='Data-general',
#         spans=[Span(start=363, end=384)],
#         references=[],
#         id='T66'),
#  Entity(mention='Device information:',
#         type='DeviceBased',
#         spans=[Span(start=658, end=677)],
#         references=[],
#         id='T67'),
#  Entity(mention='Social networks:',
#         type='SocialNetwork',
#         spans=[Span(start=941, end=957)],
#         references=[],
#         id='T68'),
#  Entity(mention='you may voluntarily provide us',
#         type='Opt-in',
#         spans=[Span(start=260, end=290)],
#         references=[],
#         id='T64'),
#  Entity(mention='respond to communications from us',
#         type='Condition',
#         spans=[Span(start=470, end=503)],
#         references=[],
#         id='T69'),
#  Entity(mention='communicate with us via email',
#         type='Condition',
#         spans=[Span(start=505, end=534)],
#         references=[],
#         id='T70'),
#  Entity(mention='share additional information about yourself through your use '
#                 'of the Services, such as on the chat feature and in games.',
#         type='Condition',
#         spans=[Span(start=538, end=657)],
#         references=[],
#         id='T71')]
# [Entity(mention='un-identified and non-identifiable information',
#         type='Data-general',
#         spans=[Span(start=60, end=106)],
#         references=[],
#         id='T1'),
#  Entity(mention='User',
#         type='User',
#         spans=[Span(start=123, end=127)],
#         references=[],
#         id='T2'),
#  Entity(mention='gathered',
#         type='collection-use',
#         spans=[Span(start=163, end=171)],
#         references=[],
#         id='T3'),
#  Entity(mention='Services',
#         type='First-party-entity',
#         spans=[Span(start=198, end=206)],
#         references=[],
#         id='T4'),
#  Entity(mention='Non-Personal Information',
#         type='Data-general',
#         spans=[Span(start=237, end=261)],
#         references=[],
#         id='T5'),
#  Entity(mention='collected',
#         type='collection-use',
#         spans=[Span(start=277, end=286)],
#         references=[],
#         id='T6'),
#  Entity(mention='technical information',
#         type='Data-general',
#         spans=[Span(start=299, end=320)],
#         references=[],
#         id='T7'),
#  Entity(mention='aggregated usage information',
#         type='Data-general',
#         spans=[Span(start=325, end=353)],
#         references=[],
#         id='T8'),
#  Entity(mention='operating system',
#         type='DeviceOperatingSystem',
#         spans=[Span(start=403, end=419)],
#         references=[],
#         id='T9'),
#  Entity(mention='type of browser',
#         type='Tracking',
#         spans=[Span(start=421, end=436)],
#         references=[],
#         id='T10'),
#  Entity(mention='screen resolution',
#         type='Data-other',
#         spans=[Span(start=438, end=455)],
#         references=[],
#         id='T11'),
#  Entity(mention='browser and keyboard language',
#         type='DeviceBased',
#         spans=[Span(start=457, end=486)],
#         references=[],
#         id='T13'),
#  Entity(mention="User's 'click-stream' and activities on the Services",
#         type='LinkClicked',
#         spans=[Span(start=492, end=544)],
#         references=[],
#         id='T14'),
#  Entity(mention='period of time the User visited the Services and related time '
#                 'stamps',
#         type='ServiceConsumptionBehavior',
#         spans=[Span(start=550, end=618)],
#         references=[],
#         id='T16'),
#  Entity(mention="User's",
#         type='User',
#         spans=[Span(start=396, end=402)],
#         references=[],
#         id='T17'),
#  Entity(mention='we',
#         type='First-party-entity',
#         spans=[Span(start=845, end=847)],
#         references=[],
#         id='T18'),
#  Entity(mention='collect',
#         type='collection-use',
#         spans=[Span(start=848, end=855)],
#         references=[],
#         id='T19'),
#  Entity(mention='you',
#         type='User',
#         spans=[Span(start=870, end=873)],
#         references=[],
#         id='T20'),
#  Entity(mention='enhance the functionality of the Services',
#         type='ServiceOptimisation',
#         spans=[Span(start=910, end=951)],
#         references=[],
#         id='T22'),
#  Entity(mention='provide you with a better user experience',
#         type='OptimisationForConsumer',
#         spans=[Span(start=959, end=1000)],
#         references=[],
#         id='T23'),
#  Entity(mention='Non-Personal Information',
#         type='Data-general',
#         spans=[Span(start=820, end=844)],
#         references=[],
#         id='T26'),
#  Entity(mention='technical information transmitted by your device',
#         type='DeviceBased',
#         spans=[Span(start=1013, end=1061)],
#         references=[],
#         id='T21'),
#  Entity(mention='certain software and hardware information',
#         type='DeviceBased',
#         spans=[Span(start=1073, end=1114)],
#         references=[],
#         id='T28'),
#  Entity(mention='type of browser',
#         type='Tracking',
#         spans=[Span(start=1125, end=1140)],
#         references=[],
#         id='T29'),
#  Entity(mention='operating system',
#         type='DeviceOperatingSystem',
#         spans=[Span(start=1145, end=1161)],
#         references=[],
#         id='T30'),
#  Entity(mention='language preference',
#         type='Language',
#         spans=[Span(start=1180, end=1199)],
#         references=[],
#         id='T31'),
#  Entity(mention='access time',
#         type='ServiceConsumptionBehavior',
#         spans=[Span(start=1201, end=1212)],
#         references=[],
#         id='T32'),
#  Entity(mention='the domain name of the website from which you linked to the '
#                 'Services',
#         type='Data-other',
#         spans=[Span(start=1217, end=1285)],
#         references=[],
#         id='T33'),
#  Entity(mention='anonymous online identifiers',
#         type='Identifier',
#         spans=[Span(start=1325, end=1353)],
#         references=[],
#         id='T34'),
#  Entity(mention='the Google Advertising ID',
#         type='Identifier',
#         spans=[Span(start=1363, end=1388)],
#         references=[],
#         id='T35'),
#  Entity(mention='the IDFA',
#         type='Identifier',
#         spans=[Span(start=1393, end=1401)],
#         references=[],
#         id='T36'),
#  Entity(mention="device's type and model",
#         type='DeviceBased',
#         spans=[Span(start=1460, end=1483)],
#         references=[],
#         id='T37'),
#  Entity(mention='system language',
#         type='DeviceBased',
#         spans=[Span(start=1485, end=1500)],
#         references=[],
#         id='T38'),
#  Entity(mention="the device's operating system",
#         type='DeviceOperatingSystem',
#         spans=[Span(start=1502, end=1531)],
#         references=[],
#         id='T39'),
#  Entity(mention='SDK version',
#         type='DeviceSoftware',
#         spans=[Span(start=1558, end=1569)],
#         references=[],
#         id='T40'),
#  Entity(mention='mobile carrier name',
#         type='DeviceBased',
#         spans=[Span(start=1571, end=1590)],
#         references=[],
#         id='T41'),
#  Entity(mention='mobile browsers installed on the device',
#         type='Tracking',
#         spans=[Span(start=1592, end=1631)],
#         references=[],
#         id='T42'),
#  Entity(mention='app history',
#         type='BrowsingBehavior',
#         spans=[Span(start=1660, end=1671)],
#         references=[],
#         id='T43'),
#  Entity(mention='usage information',
#         type='Data-general',
#         spans=[Span(start=1676, end=1693)],
#         references=[],
#         id='T44'),
#  Entity(mention='information regarding downloads and installations of mobile '
#                 'applications',
#         type='DeviceApplications',
#         spans=[Span(start=1764, end=1836)],
#         references=[],
#         id='T45'),
#  Entity(mention='any information regarding in-app events',
#         type='Data-other',
#         spans=[Span(start=1841, end=1880)],
#         references=[],
#         id='T46'),
#  Entity(mention='anonymous identifiers assigned to your device',
#         type='Identifier',
#         spans=[Span(start=1913, end=1958)],
#         references=[],
#         id='T47'),
#  Entity(mention='iOS Identifier for Advertising (IDFA)',
#         type='Identifier',
#         spans=[Span(start=1972, end=2009)],
#         references=[],
#         id='T48'),
#  Entity(mention='Google Advertising ID',
#         type='Identifier',
#         spans=[Span(start=2011, end=2032)],
#         references=[],
#         id='T49'),
#  Entity(mention='other types of device identifiers',
#         type='Identifier',
#         spans=[Span(start=2037, end=2070)],
#         references=[],
#         id='T50'),
#  Entity(mention='general location',
#         type='Location',
#         spans=[Span(start=2129, end=2145)],
#         references=[],
#         id='T24'),
#  Entity(mention='IP address',
#         type='IPAddress',
#         spans=[Span(start=2202, end=2212)],
#         references=[],
#         id='T25'),
#  Entity(mention='implicit location information',
#         type='Location',
#         spans=[Span(start=2414, end=2443)],
#         references=[],
#         id='T27'),
#  Entity(mention='information about the online ads and personalized content',
#         type='AdInteractionBehavior',
#         spans=[Span(start=2671, end=2728)],
#         references=[],
#         id='T51'),
#  Entity(mention='we',
#         type='First-party-entity',
#         spans=[Span(start=3112, end=3114)],
#         references=[],
#         id='T52'),
#  Entity(mention='collect',
#         type='collection-use',
#         spans=[Span(start=3115, end=3122)],
#         references=[],
#         id='T53'),
#  Entity(mention='information about your use of the Services',
#         type='ServiceConsumptionBehavior',
#         spans=[Span(start=3123, end=3165)],
#         references=[],
#         id='T54'),
#  Entity(mention="applications' usage",
#         type='ServiceConsumptionBehavior',
#         spans=[Span(start=3175, end=3194)],
#         references=[],
#         id='T56'),
#  Entity(mention='log files',
#         type='Tracking',
#         spans=[Span(start=3196, end=3205)],
#         references=[],
#         id='T57'),
#  Entity(mention='user activity',
#         type='ServiceConsumptionBehavior',
#         spans=[Span(start=3207, end=3220)],
#         references=[],
#         id='T58'),
#  Entity(mention='time stamps',
#         type='ServiceConsumptionBehavior',
#         spans=[Span(start=3342, end=3353)],
#         references=[],
#         id='T59'),
#  Entity(mention='alerts',
#         type='Data-other',
#         spans=[Span(start=3355, end=3361)],
#         references=[],
#         id='T60'),
#  Entity(mention='information',
#         type='Data-general',
#         spans=[Span(start=3373, end=3384)],
#         references=[],
#         id='T61'),
#  Entity(mention='collected',
#         type='collection-use',
#         spans=[Span(start=3388, end=3397)],
#         references=[],
#         id='T62'),
#  Entity(mention='troubleshooting errors and bugs',
#         type='ServiceOptimisation',
#         spans=[Span(start=3423, end=3454)],
#         references=[],
#         id='T63'),
#  Entity(mention='research and analytics purposes',
#         type='CommercialResearch',
#         spans=[Span(start=3470, end=3501)],
#         references=[],
#         id='T64'),
#  Entity(mention='your',
#         type='User',
#         spans=[Span(start=3508, end=3512)],
#         references=[],
#         id='T65'),
#  Entity(mention='collected',
#         type='collection-use',
#         spans=[Span(start=3611, end=3620)],
#         references=[],
#         id='T66'),
#  Entity(mention='We',
#         type='First-party-entity',
#         spans=[Span(start=3563, end=3565)],
#         references=[],
#         id='T67'),
#  Entity(mention='you',
#         type='User',
#         spans=[Span(start=3720, end=3723)],
#         references=[],
#         id='T69'),
#  Entity(mention='referral URL',
#         type='BrowsingReferral',
#         spans=[Span(start=3227, end=3239)],
#         references=[],
#         id='T71'),
#  Entity(mention='pages viewed',
#         type='BrowserHistory',
#         spans=[Span(start=3241, end=3253)],
#         references=[],
#         id='T72'),
#  Entity(mention='amount of time spent on particular pages',
#         type='BrowsingBehavior',
#         spans=[Span(start=3259, end=3299)],
#         references=[],
#         id='T73'),
#  Entity(mention='online browsing',
#         type='BrowsingBehavior',
#         spans=[Span(start=3301, end=3316)],
#         references=[],
#         id='T74'),
#  Entity(mention='clicks',
#         type='LinkClicked',
#         spans=[Span(start=3318, end=3324)],
#         references=[],
#         id='T75'),
#  Entity(mention='actions',
#         type='BrowsingBehavior',
#         spans=[Span(start=3326, end=3333)],
#         references=[],
#         id='T76'),
#  Entity(mention='we',
#         type='First-party-entity',
#         spans=[Span(start=2095, end=2097)],
#         references=[],
#         id='T77'),
#  Entity(mention='collect',
#         type='collection-use',
#         spans=[Span(start=2098, end=2105)],
#         references=[],
#         id='T78'),
#  Entity(mention='your',
#         type='User',
#         spans=[Span(start=2124, end=2128)],
#         references=[],
#         id='T79'),
#  Entity(mention='city',
#         type='City',
#         spans=[Span(start=2155, end=2159)],
#         references=[],
#         id='T80'),
#  Entity(mention='country',
#         type='Country',
#         spans=[Span(start=2164, end=2171)],
#         references=[],
#         id='T81'),
#  Entity(mention='identify your general location',
#         type='Purpose-other',
#         spans=[Span(start=2216, end=2246)],
#         references=[],
#         id='T82'),
#  Entity(mention='we',
#         type='First-party-entity',
#         spans=[Span(start=2398, end=2400)],
#         references=[],
#         id='T83'),
#  Entity(mention='collect',
#         type='collection-use',
#         spans=[Span(start=2406, end=2413)],
#         references=[],
#         id='T84'),
#  Entity(mention='infer that you are either interested in a place or that you '
#                 'might be at the place',
#         type='Purpose-other',
#         spans=[Span(start=2464, end=2545)],
#         references=[],
#         id='T85'),
#  Entity(mention='how many times an ad has been served to you',
#         type='AdInteractionBehavior',
#         spans=[Span(start=2800, end=2843)],
#         references=[],
#         id='T86'),
#  Entity(mention='what page the ad appeared on',
#         type='AdInteractionBehavior',
#         spans=[Span(start=2845, end=2873)],
#         references=[],
#         id='T87'),
#  Entity(mention='whether you viewed, clicked on or otherwise interacted with '
#                 'the ad',
#         type='AdInteractionBehavior',
#         spans=[Span(start=2875, end=2941)],
#         references=[],
#         id='T88'),
#  Entity(mention='ad engagement history',
#         type='AdInteractionBehavior',
#         spans=[Span(start=2943, end=2964)],
#         references=[],
#         id='T89'),
#  Entity(mention="whether you visited the advertiser's website, downloaded an "
#                 'app or purchased the product or service advertised',
#         type='AdInteractionBehavior',
#         spans=[Span(start=2969, end=3079)],
#         references=[],
#         id='T90'),
#  Entity(mention='collect',
#         type='collection-use',
#         spans=[Span(start=1005, end=1012)],
#         references=[],
#         id='T12'),
#  Entity(mention='we',
#         type='First-party-entity',
#         spans=[Span(start=1002, end=1004)],
#         references=[],
#         id='T15'),
#  Entity(mention='you',
#         type='User',
#         spans=[Span(start=967, end=970)],
#         references=[],
#         id='T91'),
#  Entity(mention='includes',
#         type='collection-use',
#         spans=[Span(start=1446, end=1454)],
#         references=[],
#         id='T92'),
#  Entity(mention='your',
#         type='User',
#         spans=[Span(start=1455, end=1459)],
#         references=[],
#         id='T93'),
#  Entity(mention='use',
#         type='collection-use',
#         spans=[Span(start=2194, end=2197)],
#         references=[],
#         id='T94'),
#  Entity(mention='we',
#         type='First-party-entity',
#         spans=[Span(start=2187, end=2189)],
#         references=[],
#         id='T95'),
#  Entity(mention='you',
#         type='User',
#         spans=[Span(start=2475, end=2478)],
#         references=[],
#         id='T96'),
#  Entity(mention='includes',
#         type='collection-use',
#         spans=[Span(start=2662, end=2670)],
#         references=[],
#         id='T97'),
#  Entity(mention='we',
#         type='First-party-entity',
#         spans=[Span(start=2729, end=2731)],
#         references=[],
#         id='T98'),
#  Entity(mention='you',
#         type='User',
#         spans=[Span(start=2771, end=2774)],
#         references=[],
#         id='T99'),
#  Entity(mention='aggregated or de-identified information',
#         type='Data-general',
#         spans=[Span(start=3756, end=3795)],
#         references=[],
#         id='T55'),
#  Entity(mention='we',
#         type='First-party-entity',
#         spans=[Span(start=3862, end=3864)],
#         references=[],
#         id='T70'),
#  Entity(mention='disclose',
#         type='third-party-sharing-disclosure',
#         spans=[Span(start=3869, end=3877)],
#         references=[],
#         id='T100'),
#  Entity(mention='others',
#         type='Third-party-entity',
#         spans=[Span(start=3884, end=3890)],
#         references=[],
#         id='T101'),
#  Entity(mention='any purpose',
#         type='Purpose-general',
#         spans=[Span(start=3918, end=3929)],
#         references=[],
#         id='T102'),
#  Entity(mention='advertising or marketing purposes',
#         type='Advertising',
#         spans=[Span(start=3943, end=3976)],
#         references=[],
#         id='T103'),
#  Entity(mention='installed apps on the device',
#         type='DeviceApplications',
#         spans=[Span(start=1733, end=1761)],
#         references=[],
#         id='T104'),
#  Entity(mention='allows us to infer',
#         type='derivation',
#         spans=[Span(start=2451, end=2469)],
#         references=[],
#         id='T105'),
#  Entity(mention='this information',
#         type='Data-general',
#         spans=[Span(start=2548, end=2564)],
#         references=[],
#         id='T106'),
#  Entity(mention='information',
#         type='Data-general',
#         spans=[Span(start=3599, end=3610)],
#         references=[],
#         id='T68'),
#  Entity(mention='may anonymize or de-identify the information',
#         type='general-safeguard-method',
#         spans=[Span(start=3566, end=3610)],
#         references=[],
#         id='T107')]
# [Entity(mention='we',
#         type='First-party-entity',
#         spans=[Span(start=448, end=450)],
#         references=[],
#         id='T1'),
#  Entity(mention='we become aware that a user who is not Legally of Age has '
#                 'shared any information',
#         type='Condition',
#         spans=[Span(start=448, end=528)],
#         references=[],
#         id='T2'),
#  Entity(mention='user who is not Legally of Age',
#         type='User',
#         spans=[Span(start=471, end=501)],
#         references=[],
#         id='T3'),
#  Entity(mention='information',
#         type='Data-general',
#         spans=[Span(start=517, end=528)],
#         references=[],
#         id='T4'),
#  Entity(mention='discard',
#         type='data-storage-retention-deletion',
#         spans=[Span(start=537, end=544)],
#         references=[],
#         id='T5')]
# [Entity(mention='We',
#         type='First-party-entity',
#         spans=[Span(start=39, end=41)],
#         references=[],
#         id='T1'),
#  Entity(mention='use',
#         type='collection-use',
#         spans=[Span(start=42, end=45)],
#         references=[],
#         id='T2'),
#  Entity(mention='your',
#         type='User',
#         spans=[Span(start=46, end=50)],
#         references=[],
#         id='T3'),
#  Entity(mention='Personal Information',
#         type='Data-general',
#         spans=[Span(start=51, end=71)],
#         references=[],
#         id='T4'),
#  Entity(mention='communicate with you',
#         type='CommunicationForCustomerCare',
#         spans=[Span(start=296, end=316)],
#         references=[],
#         id='T10'),
#  Entity(mention='keep you informed of our latest updates to our Services and '
#                 'special offers',
#         type='DirectMarketing',
#         spans=[Span(start=324, end=398)],
#         references=[],
#         id='T11'),
#  Entity(mention='market our Services',
#         type='Marketing',
#         spans=[Span(start=403, end=422)],
#         references=[],
#         id='T12'),
#  Entity(mention='serve you advertisements, including behavioral advertising',
#         type='PersonalisedAdvertising',
#         spans=[Span(start=473, end=531)],
#         references=[],
#         id='T13'),
#  Entity(mention='conduct analytics, statistical and research purposes',
#         type='ResearchAndDevelopment',
#         spans=[Span(start=536, end=588)],
#         references=[],
#         id='T14'),
#  Entity(mention='improve and customize the Services to your needs and '
#                 'interests',
#         type='ImproveExistingProductsAndServices',
#         spans=[Span(start=602, end=664)],
#         references=[],
#         id='T15'),
#  Entity(mention='support and troubleshoot the Services and to respond to your '
#                 'queries',
#         type='CustomerManagement',
#         spans=[Span(start=763, end=831)],
#         references=[],
#         id='T16'),
#  Entity(mention='further develop, customize and improve the Services based on '
#                 "Users' common preferences and uses",
#         type='OptimisationForConsumer',
#         spans=[Span(start=849, end=944)],
#         references=[],
#         id='T18'),
#  Entity(mention='identify and authenticate your access to certain features of '
#                 'the Services',
#         type='IdentityAuthentication',
#         spans=[Span(start=949, end=1022)],
#         references=[],
#         id='T19'),
#  Entity(mention='detect and prevent fraudulent and illegal activity or any '
#                 'other type of activity that may jeopardize or negatively '
#                 'affect the integrity of the Services',
#         type='FraudPreventionAndDetection',
#         spans=[Span(start=1027, end=1178)],
#         references=[],
#         id='T20'),
#  Entity(mention='identifying risks associated with your activity on our '
#                 'Services',
#         type='EnforceSecurity',
#         spans=[Span(start=1193, end=1256)],
#         references=[],
#         id='T21'),
#  Entity(mention='investigate violations of our policies and User Agreement',
#         type='OrganisationComplianceManagement',
#         spans=[Span(start=1261, end=1318)],
#         references=[],
#         id='T22'),
#  Entity(mention='enforce our policies and the User Agreement',
#         type='OrganisationComplianceManagement',
#         spans=[Span(start=1330, end=1373)],
#         references=[],
#         id='T23'),
#  Entity(mention='investigate and resolve disputes in connection with your use '
#                 'of the Services',
#         type='DisputeManagement',
#         spans=[Span(start=1378, end=1454)],
#         references=[],
#         id='T24'),
#  Entity(mention='required by law or regulation',
#         type='LegalCompliance',
#         spans=[Span(start=1463, end=1492)],
#         references=[],
#         id='T25'),
#  Entity(mention='as required by other governmental authorities',
#         type='FulfilmentOfObligation',
#         spans=[Span(start=1497, end=1542)],
#         references=[],
#         id='T26'),
#  Entity(mention='comply with a subpoena or similar legal process',
#         type='LegalCompliance',
#         spans=[Span(start=1550, end=1597)],
#         references=[],
#         id='T27'),
#  Entity(mention='respond to a government request',
#         type='FulfilmentOfObligation',
#         spans=[Span(start=1601, end=1632)],
#         references=[],
#         id='T28'),
#  Entity(mention='provide and operate the Services',
#         type='ServiceProvision',
#         spans=[Span(start=106, end=138)],
#         references=[],
#         id='T5'),
#  Entity(mention='to provide our clients with performance marketing, online '
#                 'user acquisition network, online promotions, and for the '
#                 'purposes of user attribution',
#         type='Marketing',
#         spans=[Span(start=148, end=291)],
#         references=[],
#         id='T6')]
# [Entity(mention='Company',
#         type='First-party-entity',
#         spans=[Span(start=15, end=22)],
#         references=[],
#         id='T1'),
#  Entity(mention='use',
#         type='collection-use',
#         spans=[Span(start=28, end=31)],
#         references=[],
#         id='T2'),
#  Entity(mention='your',
#         type='User',
#         spans=[Span(start=32, end=36)],
#         references=[],
#         id='T3'),
#  Entity(mention='Personal Information',
#         type='Data-general',
#         spans=[Span(start=37, end=57)],
#         references=[],
#         id='T4'),
#  Entity(mention='name',
#         type='Name',
#         spans=[Span(start=72, end=76)],
#         references=[],
#         id='T5'),
#  Entity(mention='home address',
#         type='PhysicalAddress',
#         spans=[Span(start=78, end=90)],
#         references=[],
#         id='T6'),
#  Entity(mention='email address',
#         type='EmailAddress',
#         spans=[Span(start=92, end=105)],
#         references=[],
#         id='T7'),
#  Entity(mention='telephone number',
#         type='TelephoneNumber',
#         spans=[Span(start=107, end=123)],
#         references=[],
#         id='T8'),
#  Entity(mention='providing you with promotional materials',
#         type='Marketing',
#         spans=[Span(start=202, end=242)],
#         references=[],
#         id='T10'),
#  Entity(mention='We',
#         type='First-party-entity',
#         spans=[Span(start=512, end=514)],
#         references=[],
#         id='T9'),
#  Entity(mention='share',
#         type='third-party-sharing-disclosure',
#         spans=[Span(start=524, end=529)],
#         references=[],
#         id='T11'),
#  Entity(mention='Personal Information',
#         type='Data-general',
#         spans=[Span(start=543, end=563)],
#         references=[],
#         id='T12'),
#  Entity(mention='Marketing Affiliates',
#         type='Third-party-name',
#         spans=[Span(start=573, end=593)],
#         references=[],
#         id='T13'),
#  Entity(mention='providing you different marketing offers',
#         type='Marketing',
#         spans=[Span(start=613, end=653)],
#         references=[],
#         id='T14'),
#  Entity(mention='you',
#         type='User',
#         spans=[Span(start=623, end=626)],
#         references=[],
#         id='T15'),
#  Entity(mention='use',
#         type='collection-use',
#         spans=[Span(start=753, end=756)],
#         references=[],
# ...
#         references=[],
#         id='T8'),
#  Entity(mention='protect the rights, property, or safety of Blackout Lab SL, '
#                 'our staff, our customers or other persons',
#         type='RightsFulfillment',
#         spans=[Span(start=2167, end=2268)],
#         references=[],
#         id='T9'),
#  Entity(mention='anonymised, aggregated reporting and statistics',
#         type='Data-other',
#         spans=[Span(start=2303, end=2350)],
#         references=[],
#         id='T10'),
#  Entity(mention='internal reporting or reporting to our group or other third '
#                 'parties',
#         type='CommunicationManagement',
#         spans=[Span(start=2394, end=2461)],
#         references=[],
#         id='T11'),
#  Entity(mention='store all our data and may access personal data stored within '
#                 'that storage solution when providing support and maintenance '
#                 'purposes',
#         type='Purpose-general',
#         spans=[Span(start=159, end=290)],
#         references=[],
#         id='T12'),
#  Entity(mention='verify purchases you make and provide in-app purchase '
#                 'opportunities',
#         type='CustomerOrderManagement',
#         spans=[Span(start=412, end=479)],
#         references=[],
#         id='T1')]
# [Entity(mention='any purpose other than as described in this Privacy Policy',
#         type='Purpose-general',
#         spans=[Span(start=1741, end=1799)],
#         references=[],
#         id='T1')]
# [Entity(mention='provide better services to all of users of our Service',
#         type='ImproveExistingProductsAndServices',
#         spans=[Span(start=67, end=121)],
#         references=[],
#         id='T1'),
#  Entity(mention='determining what types of editorial content and the products '
#                 'and services offered on our Service that are of the most '
#                 'interest and relevance to you',
#         type='CommercialResearch',
#         spans=[Span(start=133, end=280)],
#         references=[],
#         id='T2'),
#  Entity(mention='name',
#         type='Name',
#         spans=[Span(start=524, end=528)],
#         references=[],
#         id='T3'),
#  Entity(mention='email address',
#         type='EmailAddress',
#         spans=[Span(start=530, end=543)],
#         references=[],
#         id='T4'),
#  Entity(mention='telephone number',
#         type='TelephoneNumber',
#         spans=[Span(start=545, end=561)],
#         references=[],
#         id='T5'),
#  Entity(mention='purchase information',
#         type='Purchase',
#         spans=[Span(start=627, end=647)],
#         references=[],
#         id='T6'),
#  Entity(mention='the products or services purchased',
#         type='PurchasesAndSpendingHabit',
#         spans=[Span(start=656, end=690)],
#         references=[],
#         id='T7'),
#  Entity(mention='the dates of purchase',
#         type='Purchase',
#         spans=[Span(start=692, end=713)],
#         references=[],
#         id='T8'),
#  Entity(mention='the purchase price',
#         type='Purchase',
#         spans=[Span(start=718, end=736)],
#         references=[],
#         id='T9'),
#  Entity(mention='what editorial and advertising content you view',
#         type='ServiceConsumptionBehavior',
#         spans=[Span(start=836, end=883)],
#         references=[],
#         id='T10'),
#  Entity(mention='the products and services you use that we and our third-party '
#                 'providers offer',
#         type='ServiceConsumptionBehavior',
#         spans=[Span(start=889, end=966)],
#         references=[],
#         id='T11'),
#  Entity(mention='information about the devices you use to access our Service',
#         type='DeviceBased',
#         spans=[Span(start=1030, end=1089)],
#         references=[],
#         id='T12'),
#  Entity(mention='hardware settings',
#         type='DeviceBased',
#         spans=[Span(start=1099, end=1116)],
#         references=[],
#         id='T13'),
#  Entity(mention='browser type',
#         type='Tracking',
#         spans=[Span(start=1118, end=1130)],
#         references=[],
#         id='T14'),
#  Entity(mention='browser language',
#         type='Language',
#         spans=[Span(start=1132, end=1148)],
#         references=[],
#         id='T15'),
#  Entity(mention='date and time of your request',
#         type='ServiceConsumptionBehavior',
#         spans=[Span(start=1154, end=1183)],
#         references=[],
#         id='T16'),
#  Entity(mention='referral URL',
#         type='BrowsingReferral',
#         spans=[Span(start=1188, end=1200)],
#         references=[],
#         id='T17'),
#  Entity(mention='details about how you have used our Service',
#         type='ServiceConsumptionBehavior',
#         spans=[Span(start=1423, end=1466)],
#         references=[],
#         id='T18'),
#  Entity(mention='search queries',
#         type='BrowsingBehavior',
#         spans=[Span(start=1481, end=1495)],
#         references=[],
#         id='T19'),
#  Entity(mention='IP address',
#         type='IPAddress',
#         spans=[Span(start=1506, end=1516)],
#         references=[],
#         id='T20'),
#  Entity(mention='information about your actual location',
#         type='Data',
#         spans=[Span(start=2286, end=2324)],
#         references=[],
#         id='T22'),
#  Entity(mention='identify your browser or device',
#         type='Purpose-other',
#         spans=[Span(start=3064, end=3095)],
#         references=[],
#         id='T25'),
#  Entity(mention='information about your user preferences',
#         type='Preference',
#         spans=[Span(start=2131, end=2170)],
#         references=[],
#         id='T27'),
#  Entity(mention='other personal information',
#         type='Data-general',
#         spans=[Span(start=2175, end=2201)],
#         references=[],
#         id='T28'),
#  Entity(mention='uniquely identify your browser and collect information about '
#                 'how our visitors interact with our Service',
#         type='ServiceUsageAnalytics',
#         spans=[Span(start=1696, end=1799)],
#         references=[],
#         id='T29'),
#  Entity(mention='identify problems such as error messages from certain pages',
#         type='RepairImpairments',
#         spans=[Span(start=1820, end=1879)],
#         references=[],
#         id='T30'),
#  Entity(mention='location',
#         type='Location',
#         spans=[Span(start=2367, end=2375)],
#         references=[],
#         id='T32'),
#  Entity(mention='IP address',
#         type='IPAddress',
#         spans=[Span(start=2387, end=2397)],
#         references=[],
#         id='T33'),
#  Entity(mention='determine location',
#         type='Purpose-other',
#         spans=[Span(start=2357, end=2375)],
#         references=[],
#         id='T34'),
#  Entity(mention='identify the geographic location of that device',
#         type='Purpose-other',
#         spans=[Span(start=1622, end=1669)],
#         references=[],
#         id='T36')]
# []
# []
# [Entity(mention='directing marketing',
#         type='DirectMarketing',
#         spans=[Span(start=322, end=341)],
#         references=[],
#         id='T1')]
# []
# []
# [Entity(mention='provide you with more meaningful editorial and advertising '
#                 'content',
#         type='ProvidePersonalisedRecommendations',
#         spans=[Span(start=111, end=177)],
#         references=[],
#         id='T1'),
#  Entity(mention='offer you relevant products and services',
#         type='ProvideProductRecommendations',
#         spans=[Span(start=185, end=225)],
#         references=[],
#         id='T2'),
#  Entity(mention='maintain, protect and improve your overall experience',
#         type='OptimisationForConsumer',
#         spans=[Span(start=241, end=294)],
#         references=[],
#         id='T3'),
#  Entity(mention='these purposes',
#         type='Purpose-general',
#         spans=[Span(start=584, end=598)],
#         references=[],
#         id='T4'),
#  Entity(mention='perform our agreement or comply with your request',
#         type='CustomerClaimsManagement',
#         spans=[Span(start=937, end=986)],
#         references=[],
#         id='T5'),
#  Entity(mention='email address',
#         type='EmailAddress',
#         spans=[Span(start=1113, end=1126)],
#         references=[],
#         id='T6'),
#  Entity(mention='zip code',
#         type='PostalCode',
#         spans=[Span(start=1128, end=1136)],
#         references=[],
#         id='T7'),
#  Entity(mention='telephone number',
#         type='TelephoneNumber',
#         spans=[Span(start=1138, end=1154)],
#         references=[],
#         id='T8'),
#  Entity(mention='information about your business',
#         type='Data-general',
#         spans=[Span(start=1178, end=1209)],
#         references=[],
#         id='T9'),
#  Entity(mention='information about those purchases',
#         type='Data-general',
#         spans=[Span(start=1314, end=1347)],
#         references=[],
#         id='T10'),
#  Entity(mention='titles purchased',
#         type='Purchase',
#         spans=[Span(start=1359, end=1375)],
#         references=[],
#         id='T11'),
#  Entity(mention='quantity and dates of purchases',
#         type='Purchase',
#         spans=[Span(start=1377, end=1408)],
#         references=[],
#         id='T12'),
#  Entity(mention='method of payment',
#         type='Financial',
#         spans=[Span(start=1414, end=1431)],
#         references=[],
#         id='T13'),
#  Entity(mention='other information provided',
#         type='Data-general',
#         spans=[Span(start=1437, end=1463)],
#         references=[],
#         id='T14'),
#  Entity(mention='billing and shipping addresses',
#         type='PhysicalAddress',
#         spans=[Span(start=1472, end=1502)],
#         references=[],
#         id='T15'),
#  Entity(mention='send you promotions and other communications concerning '
#                 'business opportunities, products or services',
#         type='DirectMarketing',
#         spans=[Span(start=1692, end=1792)],
#         references=[],
#         id='T16'),
#  Entity(mention='name you provide for your EMI Profile',
#         type='Name',
#         spans=[Span(start=2166, end=2203)],
#         references=[],
#         id='T17'),
#  Entity(mention='past names associated with your EMI Account',
#         type='Name',
#         spans=[Span(start=2355, end=2398)],
#         references=[],
#         id='T18'),
#  Entity(mention='you are represented consistently across all our services',
#         type='Purpose-other',
#         spans=[Span(start=2408, end=2464)],
#         references=[],
#         id='T19'),
#  Entity(mention='a record of your communications',
#         type='Communication',
#         spans=[Span(start=2498, end=2529)],
#         references=[],
#         id='T20'),
#  Entity(mention='help solve any issues you might be facing',
#         type='CustomerCare',
#         spans=[Span(start=2533, end=2574)],
#         references=[],
#         id='T21'),
#  Entity(mention='maintain a record to assist with legal claims',
#         type='RecordManagement',
#         spans=[Span(start=2582, end=2627)],
#         references=[],
#         id='T22'),
#  Entity(mention='email address',
#         type='EmailAddress',
#         spans=[Span(start=2747, end=2760)],
#         references=[],
#         id='T23'),
#  Entity(mention='inform you about the products and services offered on our '
#                 'Service',
#         type='DirectMarketing',
#         spans=[Span(start=2764, end=2829)],
#         references=[],
#         id='T24'),
#  Entity(mention='letting you know about upcoming changes or improvements',
#         type='CommunicationManagement',
#         spans=[Span(start=2839, end=2894)],
#         references=[],
#         id='T25'),
#  Entity(mention='improve your user experience and the overall quality of our '
#                 'services',
#         type='ServiceOptimisation',
#         spans=[Span(start=2982, end=3050)],
#         references=[],
#         id='T29')]
# [Entity(mention='make that advertising as relevant as possible to the needs '
#                 'and interests of users of our Service',
#         type='PersonalisedAdvertising',
#         spans=[Span(start=295, end=391)],
#         references=[],
#         id='T2'),
#  Entity(mention='more valuable to our advertisers in being able to show our '
#                 'visitors more relevant ads',
#         type='PersonalisedAdvertising',
#         spans=[Span(start=397, end=482)],
#         references=[],
#         id='T3'),
#  Entity(mention='avoid you seeing the same ad multiple times and to detect and '
#                 'prevent click fraud',
#         type='FraudPreventionAndDetection',
#         spans=[Span(start=509, end=590)],
#         references=[],
#         id='T4'),
#  Entity(mention='IP address',
#         type='IPAddress',
#         spans=[Span(start=1106, end=1116)],
#         references=[],
#         id='T6'),
#  Entity(mention='select and provide advertising targeted to that address',
#         type='TargetedAdvertising',
#         spans=[Span(start=1120, end=1175)],
#         references=[],
#         id='T7'),
#  Entity(mention='improve the relevance of the ads you see and to measure and '
#                 'report to advertisers non-personal statistical information '
#                 'about geographical location of those website visitors who are '
#                 'viewing their ads',
#         type='OptimisationForController',
#         spans=[Span(start=1189, end=1387)],
#         references=[],
#         id='T8')]
# []
# []
# [Entity(mention='the fulfilment of your order',
#         type='CustomerOrderManagement',
#         spans=[Span(start=386, end=414)],
#         references=[],
#         id='T1'),
#  Entity(mention='the processing of your payment details',
#         type='PaymentManagement',
#         spans=[Span(start=416, end=454)],
#         references=[],
#         id='T2'),
#  Entity(mention='the provision of support services',
#         type='CustomerCare',
#         spans=[Span(start=459, end=492)],
#         references=[],
#         id='T3')]
# [Entity(mention='comments on editorial content',
#         type='Communication',
#         spans=[Span(start=101, end=130)],
#         references=[],
#         id='T1'),
#  Entity(mention='information shared via social media',
#         type='SocialMediaCommunication',
#         spans=[Span(start=135, end=170)],
#         references=[],
#         id='T2')]
# []
# [Entity(mention='comply with applicable law, regulations, legal process or '
#                 'enforceable governmental request',
#         type='LegalCompliance',
#         spans=[Span(start=555, end=645)],
#         references=[],
#         id='T1'),
#  Entity(mention='enforce any of our applicable Terms of Service, including any '
#                 'potential violations',
#         type='OrganisationComplianceManagement',
#         spans=[Span(start=651, end=733)],
#         references=[],
#         id='T2'),
#  Entity(mention='detect, prevent, or otherwise address fraud, security or '
#                 'technical issues',
#         type='FraudPreventionAndDetection',
#         spans=[Span(start=740, end=813)],
#         references=[],
#         id='T3'),
#  Entity(mention='protect against harm to the rights, property or safety of '
#                 'users of our Service or service providers, as well as the '
#                 'general public and EMI as required or permitted by law',
#         type='ProtectionOfIPR',
#         spans=[Span(start=822, end=992)],
#         references=[],
#         id='T4'),
#  Entity(mention='a merger, divestiture, restructuring, reorganization, '
#                 'dissolution or other sale or transfer of some or all of EMI’s '
#                 'assets, whether as a going concern or as part of bankruptcy, '
#                 'liquidation or similar proceeding, in which personal '
#                 'information held by EMI about our Service users is among the '
#                 'assets transferred',
#         type='OrganisationGovernance',
#         spans=[Span(start=1079, end=1388)],
#         references=[],
#         id='T5'),
#  Entity(mention='information',
#         type='Data-general',
#         spans=[Span(start=1411, end=1422)],
#         references=[],
#         id='T6'),
#  Entity(mention='show usage of EMI and third-party products and services '
#                 'offered on our Service and trends based on such categories as '
#                 'age, gender, geographical origination and other demographic '
#                 'characteristics',
#         type='ServiceUsageAnalytics',
#         spans=[Span(start=1659, end=1852)],
#         references=[],
#         id='T7')]

# %%
# data_entities = a_utils.get_data_entities_of_segments(annotations, DATA_DEF_FILE)
data_entities = a_utils.get_data_entities_of_sentences(annotations, DATA_DEF_FILE)

len(data_entities), data_entities[10]
# Out:
# (1067,
#  {'segment': 'INTRODUCTION\n\nDomains Holdings Group Limited (the "Company"), offers a global network of content-rich web, mobile and social sites, including user acquisition and media buying (including paid search, display, mobile and social advertising), content optimization (including key word search, off-page and on-page optimization), and affiliate program, both in the web and mobile ecosystem (including through websites or mobile apps operated by Company; collectively, the "Services").\nThe Company is deeply committed to safeguard the privacy expectations of its end users ("User(s)", "you" or "your"). Accordingly, we have put in place this Privacy Policy, which outlines our data protection practices, including how we collect, use, disclose and protect your Personal Information, as well as your rights with respect to your Personal Information.\nIn this Privacy Policy, you can learn about:\nWHAT INFORMATION WE COLLECT?\nMINORS\nHOW WE USE THE COLLECTED INFORMATION?\nMARKETING\nWITH WHOM WE SHARE INFORMATION?\nINTERNATIONAL TRANSFER OF INFORMATION\nTHIRD PARTY TRACKING TECHNOLOGIES\nTHIRD PARTY SERVICES\nRETENTION OF PERSONAL INFORMATION\nYOUR RIGHTS\nHOW WE KEEP YOUR INFORMATION SECURED\nCHANGES TO THE PRIVACY POLICY\nHOW TO CONTACT US\nWe encourage you to read the Privacy Policy carefully and use it to make informed decisions. By visiting or interacting with the Company\'s websites, mobile apps or other online properties, or by visiting or interacting with third party websites, mobile apps or other online properties that deploy our Service, you hereby agree to the Privacy Policy.\nIf you have any questions (or comments) concerning this Privacy Policy, you are welcome to send our Data Protection Officer at dpo@domainsholdingsgroup.info.\n\n',
#   'sentence': 'HOW WE USE THE COLLECTED INFORMATION?',
#   'entities': []})

# %% [markdown]
# ## Select training data

# %%
def has_no_entities(segment):
    return not segment["entities"]

empty_entity_indices = [i for i, segment in enumerate(data_entities) if has_no_entities(segment)]

training_set_indices = []
validation_set_indices = []
for i, segment in enumerate(data_entities):
    if not has_no_entities(segment):
        if len(training_set_indices) < 20:
            training_set_indices.append(i)
        elif len(validation_set_indices) < 3:
            validation_set_indices.append(i)

for i in empty_entity_indices:
    if len(training_set_indices) < 30:
        training_set_indices.append(i)
    elif len(validation_set_indices) < 5:
        validation_set_indices.append(i)

len(training_set_indices), len(validation_set_indices)
# Out:
# (30, 5)

# %% [markdown]
# ## Fine-tune model with specified training data

# %%
# all_data = llm_utils.as_training_data_for_data_span_of_segment(data_entities)
all_data = llm_utils.as_training_data_for_data_span_of_sentence(data_entities)
base_model = 'gpt-4o-mini-2024-07-18'
suffix = 'seg-sent-data-entities-30_train-5_val-with_empty'

# %%
job_desc_dir, fine_tune_job, test_set = llm_utils.fine_tune_with_data(
    all_data, training_set_indices, validation_set_indices,
    BRAT_DATA_PATH, DATA_DEF_FILE,
    basemodel=base_model,
    fine_tune_args={'suffix':suffix})

job_desc_dir, fine_tune_job, len(test_set), test_set[0]
# Out:
# Constructing training and validation data files (locally)...
# Uploading training and validation data files...
# Data files uploading (API calls returned).
# Creating fine-tuning job...
# ---------------------------------------------------------------------------
# InternalServerError                       Traceback (most recent call last)
# Cell In[78], line 1
# ----> 1 job_desc_dir, fine_tune_job, test_set = llm_utils.fine_tune_with_data(
#       2     all_data, training_set_indices, validation_set_indices,
#       3     BRAT_DATA_PATH, DATA_DEF_FILE,
#       4     basemodel=base_model,
#       5     fine_tune_args={'suffix':suffix})
#       7 job_desc_dir, fine_tune_job, len(test_set), test_set[0]
#
# File ~/workspaces/oxford/PP-DToU/fine-tune/notebooks/llm_utils.py:134, in fine_tune_with_data(all_data, training_set_indices, validation_set_indices, annotation_data_path, annotation_data_def, basemodel, fine_tune_args)
#     125 us('Creating fine-tuning job...')
#     127 final_fine_tune_args = {
#     128     'model': basemodel,
#     129     'training_file': training_data_remote_file.id,
#     130     'validation_file': validation_data_remote_file.id,
#     131     **fine_tune_args,
#     132 }
# --> 134 fine_tune_job = client.fine_tuning.jobs.create(**final_fine_tune_args)
#     136 us('Created fine-tuning job.')
#     138 job_desc_file = job_desc_dir / F_JOB_DESC
#
# File ~/workspaces/oxford/PP-DToU/fine-tune/.venv/lib/python3.12/site-packages/openai/resources/fine_tuning/jobs/jobs.py:144, in Jobs.create(self, model, training_file, hyperparameters, integrations, seed, suffix, validation_file, extra_headers, extra_query, extra_body, timeout)
#      63 def create(
#      64     self,
#      65     *,
#    (...)
#      78     timeout: float | httpx.Timeout | None | NotGiven = NOT_GIVEN,
#      79 ) -> FineTuningJob:
#      80     """
#      81     Creates a fine-tuning job which begins the process of creating a new model from
#      82     a given dataset.
#    (...)
#     142       timeout: Override the client-level default timeout for this request, in seconds
#     143     """
# --> 144     return self._post(
#     145         "/fine_tuning/jobs",
#     146         body=maybe_transform(
#     147             {
#     148                 "model": model,
#     149                 "training_file": training_file,
#     150                 "hyperparameters": hyperparameters,
#     151                 "integrations": integrations,
#     152                 "seed": seed,
#     153                 "suffix": suffix,
#     154                 "validation_file": validation_file,
#     155             },
#     156             job_create_params.JobCreateParams,
#     157         ),
#     158         options=make_request_options(
#     159             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#     160         ),
#     161         cast_to=FineTuningJob,
#     162     )
#
# File ~/workspaces/oxford/PP-DToU/fine-tune/.venv/lib/python3.12/site-packages/openai/_base_client.py:1260, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1246 def post(
#    1247     self,
#    1248     path: str,
#    (...)
#    1255     stream_cls: type[_StreamT] | None = None,
#    1256 ) -> ResponseT | _StreamT:
#    1257     opts = FinalRequestOptions.construct(
#    1258         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1259     )
# -> 1260     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File ~/workspaces/oxford/PP-DToU/fine-tune/.venv/lib/python3.12/site-packages/openai/_base_client.py:937, in SyncAPIClient.request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     928 def request(
#     929     self,
#     930     cast_to: Type[ResponseT],
#    (...)
#     935     stream_cls: type[_StreamT] | None = None,
#     936 ) -> ResponseT | _StreamT:
# --> 937     return self._request(
#     938         cast_to=cast_to,
#     939         options=options,
#     940         stream=stream,
#     941         stream_cls=stream_cls,
#     942         remaining_retries=remaining_retries,
#     943     )
#
# File ~/workspaces/oxford/PP-DToU/fine-tune/.venv/lib/python3.12/site-packages/openai/_base_client.py:1026, in SyncAPIClient._request(self, cast_to, options, remaining_retries, stream, stream_cls)
#    1024 if retries > 0 and self._should_retry(err.response):
#    1025     err.response.close()
# -> 1026     return self._retry_request(
#    1027         input_options,
#    1028         cast_to,
#    1029         retries,
#    1030         err.response.headers,
#    1031         stream=stream,
#    1032         stream_cls=stream_cls,
#    1033     )
#    1035 # If the response is streamed then we need to explicitly read the response
#    1036 # to completion before attempting to access the response text.
#    1037 if not err.response.is_closed:
#
# File ~/workspaces/oxford/PP-DToU/fine-tune/.venv/lib/python3.12/site-packages/openai/_base_client.py:1075, in SyncAPIClient._retry_request(self, options, cast_to, remaining_retries, response_headers, stream, stream_cls)
#    1071 # In a synchronous context we are blocking the entire thread. Up to the library user to run the client in a
#    1072 # different thread if necessary.
#    1073 time.sleep(timeout)
# -> 1075 return self._request(
#    1076     options=options,
#    1077     cast_to=cast_to,
#    1078     remaining_retries=remaining,
#    1079     stream=stream,
#    1080     stream_cls=stream_cls,
#    1081 )
#
# File ~/workspaces/oxford/PP-DToU/fine-tune/.venv/lib/python3.12/site-packages/openai/_base_client.py:1026, in SyncAPIClient._request(self, cast_to, options, remaining_retries, stream, stream_cls)
#    1024 if retries > 0 and self._should_retry(err.response):
#    1025     err.response.close()
# -> 1026     return self._retry_request(
#    1027         input_options,
#    1028         cast_to,
#    1029         retries,
#    1030         err.response.headers,
#    1031         stream=stream,
#    1032         stream_cls=stream_cls,
#    1033     )
#    1035 # If the response is streamed then we need to explicitly read the response
#    1036 # to completion before attempting to access the response text.
#    1037 if not err.response.is_closed:
#
# File ~/workspaces/oxford/PP-DToU/fine-tune/.venv/lib/python3.12/site-packages/openai/_base_client.py:1075, in SyncAPIClient._retry_request(self, options, cast_to, remaining_retries, response_headers, stream, stream_cls)
#    1071 # In a synchronous context we are blocking the entire thread. Up to the library user to run the client in a
#    1072 # different thread if necessary.
#    1073 time.sleep(timeout)
# -> 1075 return self._request(
#    1076     options=options,
#    1077     cast_to=cast_to,
#    1078     remaining_retries=remaining,
#    1079     stream=stream,
#    1080     stream_cls=stream_cls,
#    1081 )
#
# File ~/workspaces/oxford/PP-DToU/fine-tune/.venv/lib/python3.12/site-packages/openai/_base_client.py:1041, in SyncAPIClient._request(self, cast_to, options, remaining_retries, stream, stream_cls)
#    1038         err.response.read()
#    1040     log.debug("Re-raising status error")
# -> 1041     raise self._make_status_error_from_response(err.response) from None
#    1043 return self._process_response(
#    1044     cast_to=cast_to,
#    1045     options=options,
#    (...)
#    1049     retries_taken=options.get_max_retries(self.max_retries) - retries,
#    1050 )
#
# InternalServerError: Error code: 500 - {'error': {'message': 'The server had an error processing your request. Sorry about that! You can retry your request, or contact us through our help center at help.openai.com if you keep seeing this error. (Please include the request ID req_1ba4e940c152a7b11114adae3f298f86 in your email.)', 'type': 'server_error', 'param': None, 'code': None}}

# %%
llm_utils.await_fine_tune_finish_and_clean_up(wait_for_job_completion=False)
# Out:
# FineTuningJob(id='ftjob-61c0FVgYkOfjZaMwRpOjNOzo', created_at=1726265855, error=Error(code=None, message=None, param=None), fine_tuned_model='ft:gpt-4o-2024-08-06:rui:30-train-5-val-with-empty-from-api:A790JXld', finished_at=1726266269, hyperparameters=Hyperparameters(n_epochs=3, batch_size=1, learning_rate_multiplier=2), model='gpt-4o-2024-08-06', object='fine_tuning.job', organization_id='org-B2C2pNzAq4paAOvhIYdFJlSv', result_files=['file-1TTTIJ6t7DVXg51yYafkwd4J'], seed=1504396448, status='succeeded', trained_tokens=68019, training_file='file-iYtsamFpHaR3FyqGhHWNeMVm', validation_file='file-C1S6NC5e9VWZrwgmuFzkDxVR', estimated_finish=None, integrations=[], user_provided_suffix='30_train-5_val-with_empty-from_api')

# %%
fine_tuned_model_id = 'ft:gpt-4o-mini-2024-07-18:rui:30_train-5_val-content_only-from_api:A6KhgqGM'
fine_tuned_model_id = 'ft:gpt-4o-mini-2024-07-18:rui:30-train-5-val-content-only-from-api:A6cig7w6'

# %% [markdown]
# ## Run model evaluation

# %%
training_set, validation_set, test_set, fine_tuned_model_id = llm_utils.load_eval_info()

len(training_set), len(validation_set), len(test_set)

# %%
messages_list = [data['messages'][:-1] for data in test_set]
correct_outputs = [data['messages'][-1]['content'] for data in test_set]
dir_name, obj_model_outputs = llm_utils.query_llm(fine_tuned_model_id, messages_list, correct_outputs=correct_outputs)

dir_name, len(obj_model_outputs)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# 100%|██████████| 10/10 [00:04<00:00,  2.08it/s]
# ('eval-2024-09-14-00-12-51-ft:gpt-4o-mini-2024-07-18:rui:30-training-data-with-content-and-10-val:A6KhgqGM',
#  10)

# %% [markdown]
# ### Or, evaluate an existing model
# Thus we don't need to split training data out

# %%
custom_model_id = 'gpt-4o-mini-2024-07-18'
all_data = llm_utils.as_training_data_for_data_span(data_entities)
messages_list = [data['messages'][:-1] for data in all_data]
correct_outputs = [data['messages'][-1]['content'] for data in all_data]
dir_name, obj_model_outputs = llm_utils.query_llm(custom_model_id, messages_list, correct_outputs=correct_outputs)

dir_name, len(obj_model_outputs)
# Out:
# 100%|██████████| 181/181 [03:05<00:00,  1.03s/it]
# ('eval-2024-09-13-22-59-04-gpt-4o-mini-2024-07-18', 181)

# %% [markdown]
# ## Calculate statistics from model performance (from saved query results)

# %%
dir_name = '2024-09-13-00-44-00-6cbf289f-798c-46ff-8d72-221b0da1099e'
dir_name = '2024-09-13-14-48-28-ft:gpt-4o-mini-2024-07-18:rui:30-train-5-val-no-empty-from-api:A70TvfoL'

# %%
desc, saved_queries = list(llm_utils.load_saved_llm_queries())
desc, len(saved_queries), saved_queries[0]
# Out:
# ({'model': 'gpt-4o-mini-2024-07-18'},
#  181,
#  {'input': [{'role': 'system',
#     'content': 'You are an annotation expert. You will be given a segment of a privacy policy of a web or mobile application, and will be asked to annotate entities in it.'},
#    {'role': 'user',
#     'content': 'Please annotate the given segment of privacy policy for data entities, and adhere to the following guidelines:\n\nIMPORTANT: Filtering Out General Phrases\nBefore annotating, carefully check each potential data entity. DO NOT annotate general phrases that do not provide specific data types.\nExamples of general phrases to omit include, but are not limited to:\n\n"your personal information"\n"the information you share (with us)"\n"the information we collect about you"\n"other data"\n"information about you"\n"personal information"\n"user information"\n"customer data"\n"collected information"\n"any information"\n\nIf a phrase does not clearly indicate a specific type of personal data, DO NOT include it in your annotations.\n\nData entities are refers to the phrases that mention PERSONAL DATA OF THE USER which is being mentioned in one of the following context types:\n1. first-party-collection-use - the policy segment mentions collection, usage, or processing of this datum by the first party (the application).\n2. third-party-collection-use - the policy segment mentions collection, usage, or processing of this datum by a third party.\n3. third-party-sharing-disclosure - the policy segment mentions sharing, or disclosure of this datum to a third party.\n4. data-storage-retention-deletion - the policy segment mentions storage, retention, or deletion of this datum.\n5. data-security-protection - the policy segment mentions how this datum is being protected.\n\nNote the following!\n1. Personal user data that is mentioned outside of one of these contexts does not classify as data entity and should NOT be annotated.\n2. Multiple contexts may apply to the same data entity.\n3. Tracking technologies such as cookies, web beacons, etc. are technologies, hence does not classify as data entity and should NOT be annotated.\n4. The data segment that you receive might be empty or not contain any information on usage of concrete personal user data - that\'s normal, and you should just return an empty list.\n\nProvide the output as a list of data entities with the following details for each entity:\n1. The type of the context in which this datum is mentioned.\n2. The exact text of the data entity as it appears in the text segment.\n\nHere is the privacy policy segment to annotate:\n\n101 Great Goals Privacy Policy\nLast revised: May 25, 2018\n\n\n'}],
#   'output': '[]',
#   'correct_output': '[]'})

# %%
import numpy as np
import sys

# num_datapoints = len(saved_queries)

def calc_statistics(saved_queries):
    result_score_list = []
    empty_result_score_list = []
    non_empty_result_score_list = []

    failed = {}
    for i, (model_output, correct_output) in enumerate([(query['output'], query['correct_output']) for query in saved_queries]):
        try:
            model_output_parsed = json.loads(model_output)
        except json.JSONDecodeError as e:
            failed[i] = (model_output, correct_output)
            continue
        correct_output_parsed = json.loads(correct_output)
        try:
            result_score = llm_utils.precision_accuracy_f1(correct_output_parsed, model_output_parsed)
        except TypeError as e:
            failed[i] = (model_output, correct_output)
            continue
        result_score_list.append(result_score)
        if correct_output_parsed:
            non_empty_result_score_list.append(result_score)
        else:
            empty_result_score_list.append(result_score)

    return result_score_list, non_empty_result_score_list, empty_result_score_list, failed


def calc_and_print_statistics(desc, saved_queries):
    result_score_list, non_empty_result_score_list, empty_result_score_list, failed = calc_statistics(saved_queries)

    print(f"Stat for eval with desc: {desc}")
    print(f"  {len(result_score_list)} valid datapoints, avg. precission, recall, f1:", np.mean(result_score_list, axis=0))
    print(f"  {len(non_empty_result_score_list)} (ought to be) non-empty datapoints, avg. precission, recall, f1:", np.mean(non_empty_result_score_list, axis=0))
    print(f"  {len(empty_result_score_list)} (ought to be) empty datapoints, avg. precission, recall, f1:", np.mean(empty_result_score_list, axis=0))
    print(f"  {len(failed)} datapoints are not valid JSON")
    print("  ", end=''), pprint(failed)


calc_and_print_statistics(desc, saved_queries)
# Out:
# Stat for eval with desc: {'model': 'gpt-4o-mini-2024-07-18'}
#   74 valid datapoints, avg. precission, recall, f1: [0.94594595 0.94594595 0.94594595]
#   4 (ought to be) non-empty datapoints, avg. precission, recall, f1: [0. 0. 0.]
#   70 (ought to be) empty datapoints, avg. precission, recall, f1: [1. 1. 1.]
#   107 datapoints are not valid JSON
#   {1: ('```json\n[]\n```', '[]'),
#  3: ('```json\n[]\n```', '[]'),
#  5: ('```json\n[]\n```', '[]'),
#  6: ('```json\n[]\n```', '[]'),
#  10: ('```json\n'
#       '[\n'
#       '    {\n'
#       '        "context_type": "first-party-collection-use",\n'
#       '        "data_entity": "full name"\n'
#       '    },\n'
#       '    {\n'
#       '        "context_type": "first-party-collection-use",\n'
#       '        "data_entity": "email address"\n'
#       '    },\n'
#       '    {\n'
#       '        "context_type": "first-party-collection-use",\n'
#       '        "data_entity": "device\'s unique identifiers"\n'
#       '    },\n'
#       '    {\n'
#       '        "context_type": "first-party-collection-use",\n'
#       '        "data_entity": "browser fingerprinting"\n'
#       '    },\n'
#       '    {\n'
#       '        "context_type": "first-party-collection-use",\n'
#       '        "data_entity": "IP address"\n'
#       '    },\n'
#       '    {\n'
#       '        "context_type": "first-party-collection-use",\n'
#       '        "data_entity": "geo-location data"\n'
#       '    },\n'
#       '    {\n'
#       '        "context_type": "first-party-collection-use",\n'
#       '        "data_entity": "name"\n'
#       '    },\n'
#       '    {\n'
#       '        "context_type": "first-party-collection-use",\n'
#       '        "data_entity": "birthdate"\n'
#       '    },\n'
#       '    {\n'
#       '        "context_type": "first-party-collection-use",\n'
#       '        "data_entity": "profile picture"\n'
#       '    },\n'
#       '    {\n'
#       '        "context_type": "first-party-collection-use",\n'
#       '        "data_entity": "friends\' list"\n'
#       '    },\n'
#       '    {\n'
#       '        "context_type": "first-party-collection-use",\n'
#       '        "data_entity": "name"\n'
#       '    },\n'
#       '    {\n'
#       '        "context_type": "first-party-collection-use",\n'
#       '        "data_entity": "email address"\n'
#       '    },\n'
#       '    {\n'
#       '        "context_type": "first-party-collection-use",\n'
#       '        "data_entity": "phone number"\n'
#       '    },\n'
#       '    {\n'
#       '        "context_type": "first-party-collection-use",\n'
#       '        "data_entity": "date of birth"\n'
#       '    },\n'
#       '    {\n'
#       '        "context_type": "third-party-collection-use",\n'
#       '        "data_entity": "credit history"\n'
#       '    },\n'
#       '    {\n'
#       '        "context_type": "third-party-collection-use",\n'
#       '        "data_entity": "financial information"\n'
#       '    },\n'
#       '    {\n'
#       '        "context_type": "third-party-collection-use",\n'
#       '        "data_entity": "identity verification information"\n'
#       '    }\n'
#       ']\n'
#       '```',
#       '["name", "profile picture", "friends\' list", "name", "other financial '
#       'information", "geo-location data", "contact details", "full name", '
#       '"UDID", "Contact details:"]'),
#  11: ('```json\n[]\n```',
#       '["type of browser", "type of browser", "language preference", '
#       '"anonymous online identifiers", "the Google Advertising ID", "the '
#       'IDFA", "mobile browsers installed on the device", "anonymous '
#       'identifiers assigned to your device", "iOS Identifier for Advertising '
#       '(IDFA)", "Google Advertising ID", "other types of device identifiers", '
#       '"general location", "implicit location information", "log files", '
#       '"city", "country"]'),
#  14: ('```json\n'
#       '[\n'
#       '    {\n'
#       '        "context_type": "first-party-collection-use",\n'
#       '        "data_entity": "your name"\n'
#       '    },\n'
#       '    {\n'
#       '        "context_type": "first-party-collection-use",\n'
#       '        "data_entity": "home address"\n'
#       '    },\n'
#       '    {\n'
#       '        "context_type": "first-party-collection-use",\n'
#       '        "data_entity": "email address"\n'
#       '    },\n'
#       '    {\n'
#       '        "context_type": "first-party-collection-use",\n'
#       '        "data_entity": "telephone number"\n'
#       '    },\n'
#       '    {\n'
#       '        "context_type": "third-party-sharing-disclosure",\n'
#       '        "data_entity": "Personal Information"\n'
#       '    },\n'
#       '    {\n'
#       '        "context_type": "third-party-collection-use",\n'
#       '        "data_entity": "Personal Information"\n'
#       '    },\n'
#       '    {\n'
#       '        "context_type": "third-party-sharing-disclosure",\n'
#       '        "data_entity": "Personal Information"\n'
#       '    },\n'
#       '    {\n'
#       '        "context_type": "third-party-collection-use",\n'
#       '        "data_entity": "Personal Information"\n'
#       '    }\n'
#       ']\n'
#       '```',
#       '["name"]'),
#  15: ('```json\n'
#       '[\n'
#       '    {\n'
#       '        "context_type": "third-party-sharing-disclosure",\n'
#       '        "data_entity": "Personal Information"\n'
#       '    },\n'
#       '    {\n'
#       '        "context_type": "third-party-sharing-disclosure",\n'
#       '        "data_entity": "Personal Information"\n'
#       '    },\n'
#       '    {\n'
#       '        "context_type": "third-party-sharing-disclosure",\n'
#       '        "data_entity": "information about how you have interacted with '
#       'such websites or apps"\n'
#       '    },\n'
#       '    {\n'
#       '        "context_type": "third-party-sharing-disclosure",\n'
#       '        "data_entity": "Personal Information"\n'
#       '    },\n'
#       '    {\n'
#       '        "context_type": "third-party-sharing-disclosure",\n'
#       '        "data_entity": "Personal Information"\n'
#       '    },\n'
#       '    {\n'
#       '        "context_type": "third-party-sharing-disclosure",\n'
#       '        "data_entity": "Personal Information"\n'
#       '    },\n'
#       '    {\n'
#       '        "context_type": "third-party-sharing-disclosure",\n'
#       '        "data_entity": "Personal Information"\n'
#       '    },\n'
#       '    {\n'
#       '        "context_type": "third-party-sharing-disclosure",\n'
#       '        "data_entity": "Personal Information"\n'
#       '    },\n'
#       '    {\n'
#       '        "context_type": "third-party-sharing-disclosure",\n'
#       '        "data_entity": "Personal Information"\n'
#       '    },\n'
#       '    {\n'
#       '        "context_type": "data-storage-retention-deletion",\n'
#       '        "data_entity": "Storing such information on our behalf"\n'
#       '    },\n'
#       '    {\n'
#       '        "context_type": "first-party-collection-use",\n'
#       '        "data_entity": "Processing such information"\n'
#       '    },\n'
#       '    {\n'
#       '        "context_type": "first-party-collection-use",\n'
#       '        "data_entity": "auditing our operations"\n'
#       '    },\n'
#       '    {\n'
#       '        "context_type": "first-party-collection-use",\n'
#       '        "data_entity": "detect and prevent fraudulent or illegal '
#       'activity"\n'
#       '    },\n'
#       '    {\n'
#       '        "context_type": "first-party-collection-use",\n'
#       '        "data_entity": "Communicating targeted advertising"\n'
#       '    },\n'
#       '    {\n'
#       '        "context_type": "third-party-sharing-disclosure",\n'
#       '        "data_entity": "whenever we believe in good faith that '
#       'disclosure is necessary to protect our rights or legal claims"\n'
#       '    }\n'
#       ']\n'
#       '```',
#       '["geo-location"]'),
#  16: ('```json\n'
#       '[\n'
#       '    {\n'
#       '        "context_type": "third-party-sharing-disclosure",\n'
#       '        "data_entity": "your Personal Information"\n'
#       '    },\n'
#       '    {\n'
#       '        "context_type": "data-security-protection",\n'
#       '        "data_entity": "your Personal Information"\n'
#       '    }\n'
#       ']\n'
#       '```',
#       '[]'),
#  17: ('```json\n[]\n```', '[]'),
#  19: ('```json\n[]\n```', '[]'),
#  20: ('```json\n[]\n```', '[]'),
#  21: ('```json\n'
#       '[\n'
#       '    {\n'
#       '        "context_type": "data-storage-retention-deletion",\n'
#       '        "text": "basic account information, including your name, '
#       'username, and email address"\n'
#       '    },\n'
#       '    {\n'
#       '        "context_type": "data-storage-retention-deletion",\n'
#       '        "text": "location information"\n'
#       '    },\n'
#       '    {\n'
#       '        "context_type": "data-storage-retention-deletion",\n'
#       '        "text": "your data"\n'
#       '    },\n'
#       '    {\n'
#       '        "context_type": "data-storage-retention-deletion",\n'
#       '        "text": "certain information in backup"\n'
#       '    }\n'
#       ']\n'
#       '```',
#       '["name", "username", "location information", "information about the '
#       'things you like or dislike"]'),
#  24: ('```json\n[]\n```', '["location"]'),
#  31: ('```json\n'
#       '[\n'
#       '    {\n'
#       '        "context": "first-party-collection-use",\n'
#       '        "data_entity": "a unique username you choose"\n'
#       '    },\n'
#       '    {\n'
#       '        "context": "first-party-collection-use",\n'
#       '        "data_entity": "a password"\n'
#       '    },\n'
#       '    {\n'
#       '        "context": "first-party-collection-use",\n'
#       '        "data_entity": "an e-mail address"\n'
#       '    },\n'
#       '    {\n'
#       '        "context": "first-party-collection-use",\n'
#       '        "data_entity": "your date of birth"\n'
#       '    },\n'
#       '    {\n'
#       '        "context": "first-party-collection-use",\n'
#       '        "data_entity": "a profile picture"\n'
#       '    },\n'
#       '    {\n'
#       '        "context": "first-party-collection-use",\n'
#       '        "data_entity": "a name"\n'
#       '    },\n'
#       '    {\n'
#       '        "context": "first-party-collection-use",\n'
#       '        "data_entity": "debit card or credit card number"\n'
#       '    },\n'
#       '    {\n'
#       '        "context": "first-party-collection-use",\n'
#       '        "data_entity": "its associated account information"\n'
#       '    },\n'
#       '    {\n'
#       '        "context": "first-party-collection-use",\n'
#       '        "data_entity": "any information you send through our services"\n'
#       '    }\n'
#       ']\n'
#       '```',
#       '["username", "password", "profile picture", "name", "identifiable '
#       'information"]'),
#  32: ('```json\n'
#       '[\n'
#       '    {\n'
#       '        "context_type": "first-party-collection-use",\n'
#       '        "text": "information about which services you use and how you '
#       'use them"\n'
#       '    },\n'
#       '    {\n'
#       '        "context_type": "first-party-collection-use",\n'
#       '        "text": "how you interact with our services, such as what '
#       'sections you look at, what you search for, what posts and comments you '
#       'upload, or what posts and comments you upvote or downvote"\n'
#       '    },\n'
#       '    {\n'
#       '        "context_type": "first-party-collection-use",\n'
#       '        "text": "content you create on our services"\n'
#       '    },\n'
#       '    {\n'
#       '        "context_type": "first-party-collection-use",\n'
#       '        "text": "The images, videos, and text you upload"\n'
#       '    },\n'
#       '    {\n'
#       '        "context_type": "first-party-collection-use",\n'
#       '        "text": "when you created the content"\n'
#       '    },\n'
#       '    {\n'
#       '        "context_type": "first-party-collection-use",\n'
#       '        "text": "where you created the content"\n'
#       '    },\n'
#       '    {\n'
#       '        "context_type": "first-party-collection-use",\n'
#       '        "text": "how you created the content such as device '
#       'information"\n'
#       '    },\n'
#       '    {\n'
#       '        "context_type": "first-party-collection-use",\n'
#       '        "text": "how other users interact with your content"\n'
#       '    },\n'
#       '    {\n'
#       '        "context_type": "first-party-collection-use",\n'
#       '        "text": "device information"\n'
#       '    },\n'
#       '    {\n'
#       '        "context_type": "first-party-collection-use",\n'
#       '        "text": "Information about your hardware and software, such as '
#       'hardware model, operating system version, device memory, advertising '
#       'identifiers, unique application identifiers, unique device identifiers, '
#       'and language"\n'
#       '    },\n'
#       '    {\n'
#       '        "context_type": "first-party-collection-use",\n'
#       '        "text": "Information about your wireless and mobile network '
#       'connections, such as your type of network connection"\n'
#       '    },\n'
#       '    {\n'
#       '        "context_type": "first-party-collection-use",\n'
#       '        "text": "images and other information from your devices’s '
#       'camera and photos"\n'
#       '    },\n'
#       '    {\n'
#       '        "context_type": "first-party-collection-use",\n'
#       '        "text": "information about your location"\n'
#       '    },\n'
#       '    {\n'
#       '        "context_type": "first-party-collection-use",\n'
#       '        "text": "precise location using methods that include GPS, '
#       'wireless networks, and Wi-Fi access points"\n'
#       '    },\n'
#       '    {\n'
#       '        "context_type": "first-party-collection-use",\n'
#       '        "text": "log information when you use our services"\n'
#       '    },\n'
#       '    {\n'
#       '        "context_type": "first-party-collection-use",\n'
#       '        "text": "Details about how you’ve used our services"\n'
#       '    },\n'
#       '    {\n'
#       '        "context_type": "first-party-collection-use",\n'
#       '        "text": "device information, such as web browser type and '
#       'language"\n'
#       '    },\n'
#       '    {\n'
#       '        "context_type": "first-party-collection-use",\n'
#       '        "text": "Access times"\n'
#       '    },\n'
#       '    {\n'
#       '        "context_type": "first-party-collection-use",\n'
#       '        "text": "Pages and content viewed"\n'
#       '    },\n'
#       '    {\n'
#       '        "context_type": "first-party-collection-use",\n'
#       '        "text": "IP address"\n'
#       '    },\n'
#       '    {\n'
#       '        "context_type": "first-party-collection-use",\n'
#       '        "text": "Identifiers associated with cookies or other '
#       'technologies that may uniquely identify your device or browser"\n'
#       '    },\n'
#       '    {\n'
#       '        "context_type": "first-party-collection-use",\n'
#       '        "text": "Pages you visited before or after visiting our website '
#       'or using our service"\n'
#       '    }\n'
#       ']\n'
#       '```',
#       '["Where you created the content", "information about how other users '
#       'interact with your content", "advertising identifiers", "unique '
#       'application identifiers", "language", "type of network connection", '
#       '"images", "other information from your devices\\u2019s camera and '
#       'photos", "information about your location", "log information", "web '
#       'browser type", "language", "Identifiers associated with cookies", '
#       '"other technologies that may uniquely identify your device or '
#       'browser"]'),
#  33: ('```json\n'
#       '[\n'
#       '    {\n'
#       '        "context_type": "third-party-collection-use",\n'
#       '        "data_entity": "information from our affiliates and third '
#       'parties"\n'
#       '    },\n'
#       '    {\n'
#       '        "context_type": "third-party-collection-use",\n'
#       '        "data_entity": "information so you can create or access your '
#       '9GAG account"\n'
#       '    },\n'
#       '    {\n'
#       '        "context_type": "third-party-sharing-disclosure",\n'
#       '        "data_entity": "information with us to help target or measure '
#       'ad performance"\n'
#       '    }\n'
#       ']\n'
#       '```',
#       '[]'),
#  35: ('```json\n'
#       '[\n'
#       '    {\n'
#       '        "context_type": "third-party-sharing-disclosure",\n'
#       '        "data_entity": "your name"\n'
#       '    },\n'
#       '    {\n'
#       '        "context_type": "third-party-sharing-disclosure",\n'
#       '        "data_entity": "username"\n'
#       '    },\n'
#       '    {\n'
#       '        "context_type": "third-party-sharing-disclosure",\n'
#       '        "data_entity": "profile pictures"\n'
#       '    },\n'
#       '    {\n'
#       '        "context_type": "third-party-sharing-disclosure",\n'
#       '        "data_entity": "image or video posts"\n'
#       '    },\n'
#       '    {\n'
#       '        "context_type": "third-party-sharing-disclosure",\n'
#       '        "data_entity": "how you interacted with our services"\n'
#       '    },\n'
#       '    {\n'
#       '        "context_type": "third-party-sharing-disclosure",\n'
#       '        "data_entity": "content you saved"\n'
#       '    },\n'
#       '    {\n'
#       '        "context_type": "third-party-sharing-disclosure",\n'
#       '        "data_entity": "comments you post"\n'
#       '    },\n'
#       '    {\n'
#       '        "context_type": "third-party-sharing-disclosure",\n'
#       '        "data_entity": "content you upvote and downvote"\n'
#       '    },\n'
#       '    {\n'
#       '        "context_type": "third-party-sharing-disclosure",\n'
#       '        "data_entity": "public information like your name"\n'
#       '    },\n'
#       '    {\n'
#       '        "context_type": "third-party-sharing-disclosure",\n'
#       '        "data_entity": "username"\n'
#       '    },\n'
#       '    {\n'
#       '        "context_type": "third-party-sharing-disclosure",\n'
#       '        "data_entity": "profile pictures"\n'
#       '    },\n'
#       '    {\n'
#       '        "context_type": "third-party-sharing-disclosure",\n'
#       '        "data_entity": "content submissions"\n'
#       '    },\n'
#       '    {\n'
#       '        "context_type": "third-party-sharing-disclosure",\n'
#       '        "data_entity": "saved content set to be viewable by everyone"\n'
#       '    },\n'
#       '    {\n'
#       '        "context_type": "third-party-sharing-disclosure",\n'
#       '        "data_entity": "content from our services that you share on '
#       'other services"\n'
#       '    },\n'
#       '    {\n'
#       '        "context_type": "third-party-sharing-disclosure",\n'
#       '        "data_entity": "your information"\n'
#       '    }\n'
#       ']\n'
#       '```',
#       '["name", "username", "profile pictures", "image or video posts", "the '
#       'content you upvote and downvote", "name", "username", "profile '
#       'pictures"]'),
#  39: ('```json\n[]\n```',
#       '["Identifiers", "name", "profile photo", "gender", "age", "browser '
#       'type", "language"]'),
#  42: ('```json\n[]\n```', '[]'),
#  46: ('```json\n'
#       '[\n'
#       '    {\n'
#       '        "context_type": "first-party-collection-use",\n'
#       '        "data_entity": "name"\n'
#       '    },\n'
#       '    {\n'
#       '        "context_type": "first-party-collection-use",\n'
#       '        "data_entity": "address"\n'
#       '    },\n'
#       '    {\n'
#       '        "context_type": "first-party-collection-use",\n'
#       '        "data_entity": "telephone number"\n'
#       '    },\n'
#       '    {\n'
#       '        "context_type": "first-party-collection-use",\n'
#       '        "data_entity": "email address"\n'
#       '    },\n'
#       '    {\n'
#       '        "context_type": "data-storage-retention-deletion",\n'
#       '        "data_entity": "personal information"\n'
#       '    }\n'
#       ']\n'
#       '```',
#       '["name"]'),
#  47: ('```json\n[]\n```', '[]'),
#  50: ('```json\n[]\n```', '["contact information", "your Facebook friends"]'),
#  51: ('```json\n[]\n```', '[]'),
#  52: ('```json\n[]\n```',
#       '["locale", "your viewing of and interactions with advertising"]'),
#  53: ('```json\n'
#       '[\n'
#       '    {\n'
#       '        "context": "first-party-collection-use",\n'
#       '        "text": "application usage, access, session times and in-app '
#       'purchases"\n'
#       '    },\n'
#       '    {\n'
#       '        "context": "first-party-collection-use",\n'
#       '        "text": "unique device ID (persistent / non-persistent)"\n'
#       '    },\n'
#       '    {\n'
#       '        "context": "first-party-collection-use",\n'
#       '        "text": "hardware type"\n'
#       '    },\n'
#       '    {\n'
#       '        "context": "first-party-collection-use",\n'
#       '        "text": "media access control (“MAC”) address"\n'
#       '    },\n'
#       '    {\n'
#       '        "context": "first-party-collection-use",\n'
#       '        "text": "version of your operating system (“OS”)"\n'
#       '    },\n'
#       '    {\n'
#       '        "context": "first-party-collection-use",\n'
#       '        "text": "email address (if you have connected to Facebook)"\n'
#       '    },\n'
#       '    {\n'
#       '        "context": "data-storage-retention-deletion",\n'
#       '        "text": "unique user ID"\n'
#       '    },\n'
#       '    {\n'
#       '        "context": "data-storage-retention-deletion",\n'
#       '        "text": "profile information"\n'
#       '    }\n'
#       ']\n'
#       '```',
#       '["your unique device ID", "unique user ID", "profile information", '
#       '"unique user ID"]'),
#  54: ('```json\n'
#       '[\n'
#       '    {\n'
#       '        "context_type": "first-party-collection-use",\n'
#       '        "data_entity": "data and information about you and your '
#       'device"\n'
#       '    },\n'
#       '    {\n'
#       '        "context_type": "first-party-collection-use",\n'
#       '        "data_entity": "your game and device usage"\n'
#       '    },\n'
#       '    {\n'
#       '        "context_type": "first-party-collection-use",\n'
#       '        "data_entity": "online behavior and interests"\n'
#       '    },\n'
#       '    {\n'
#       '        "context_type": "third-party-collection-use",\n'
#       '        "data_entity": "Advertising IDs"\n'
#       '    },\n'
#       '    {\n'
#       '        "context_type": "third-party-collection-use",\n'
#       '        "data_entity": "data and information about you"\n'
#       '    },\n'
#       '    {\n'
#       '        "context_type": "third-party-collection-use",\n'
#       '        "data_entity": "Service session activity"\n'
#       '    },\n'
#       '    {\n'
#       '        "context_type": "third-party-collection-use",\n'
#       '        "data_entity": "viewing of and interaction with an '
#       'advertisement"\n'
#       '    },\n'
#       '    {\n'
#       '        "context_type": "third-party-collection-use",\n'
#       '        "data_entity": "device identifier"\n'
#       '    },\n'
#       '    {\n'
#       '        "context_type": "third-party-collection-use",\n'
#       '        "data_entity": "MAC address"\n'
#       '    },\n'
#       '    {\n'
#       '        "context_type": "third-party-collection-use",\n'
#       '        "data_entity": "IMEI"\n'
#       '    },\n'
#       '    {\n'
#       '        "context_type": "third-party-collection-use",\n'
#       '        "data_entity": "geo-location information"\n'
#       '    },\n'
#       '    {\n'
#       '        "context_type": "third-party-collection-use",\n'
#       '        "data_entity": "IP address"\n'
#       '    },\n'
#       '    {\n'
#       '        "context_type": "third-party-collection-use",\n'
#       '        "data_entity": "crash reports"\n'
#       '    },\n'
#       '    {\n'
#       '        "context_type": "third-party-sharing-disclosure",\n'
#       '        "data_entity": "device identifier"\n'
#       '    }\n'
#       ']\n'
#       '```',
#       '["device location", "geo-location information"]'),
#  55: ('```json\n'
#       '[\n'
#       '    {\n'
#       '        "context_type": "third-party-sharing-disclosure",\n'
#       '        "data_entity": "personal information"\n'
#       '    },\n'
#       '    {\n'
#       '        "context_type": "third-party-sharing-disclosure",\n'
#       '        "data_entity": "information"\n'
#       '    },\n'
#       '    {\n'
#       '        "context_type": "third-party-sharing-disclosure",\n'
#       '        "data_entity": "personal information"\n'
#       '    },\n'
#       '    {\n'
#       '        "context_type": "third-party-sharing-disclosure",\n'
#       '        "data_entity": "information"\n'
#       '    },\n'
#       '    {\n'
#       '        "context_type": "third-party-sharing-disclosure",\n'
#       '        "data_entity": "personal information"\n'
#       '    },\n'
#       '    {\n'
#       '        "context_type": "third-party-sharing-disclosure",\n'
#       '        "data_entity": "information"\n'
#       '    }\n'
#       ']\n'
#       '```',
#       '[]'),
#  57: ('```json\n[]\n```', '["personally identifiable information (PII)"]'),
#  58: ('```json\n[]\n```',
#       '["Domain from which you access the Internet", "information about the '
#       'browser you used", "Address of the website that connected you to a CMS '
#       'website"]'),
#  59: ('```json\n[]\n```', '["opinions and feedback"]'),
#  62: ('```json\n'
#       '[\n'
#       '    {\n'
#       '        "context_type": "first-party-collection-use",\n'
#       '        "data_entity": "email address"\n'
#       '    },\n'
#       '    {\n'
#       '        "context_type": "data-storage-retention-deletion",\n'
#       '        "data_entity": "personally identifiable information"\n'
#       '    },\n'
#       '    {\n'
#       '        "context_type": "data-storage-retention-deletion",\n'
#       '        "data_entity": "personal information"\n'
#       '    },\n'
#       '    {\n'
#       '        "context_type": "data-security-protection",\n'
#       '        "data_entity": "personal identifier (name, personal email '
#       'address, home mailing address, personal or mobile phone number)"\n'
#       '    }\n'
#       ']\n'
#       '```',
#       '["personally identifiable information", "name", "personal identifier"]'),
#  65: ('```json\n[]\n```',
#       '["PII", "PII", "PII", "tracking pixels", "tracking pixels"]'),
#  68: ('```json\n[]\n```', '[]'),
#  69: ('```json\n[]\n```', '[]'),
#  71: ('```json\n'
#       '[\n'
#       '    {\n'
#       '        "context_type": "third-party-sharing-disclosure",\n'
#       '        "data_entity": "Personal Information"\n'
#       '    },\n'
#       '    {\n'
#       '        "context_type": "third-party-sharing-disclosure",\n'
#       '        "data_entity": "Personal Information"\n'
#       '    },\n'
#       '    {\n'
#       '        "context_type": "third-party-sharing-disclosure",\n'
#       '        "data_entity": "Personal Information"\n'
#       '    },\n'
#       '    {\n'
#       '        "context_type": "third-party-sharing-disclosure",\n'
#       '        "data_entity": "Personal Information"\n'
#       '    },\n'
#       '    {\n'
#       '        "context_type": "third-party-collection-use",\n'
#       '        "data_entity": "Personal Information"\n'
#       '    }\n'
#       ']\n'
#       '```',
#       '[]'),
#  73: ('```json\n[]\n```', '[]'),
#  74: ('```json\n[]\n```', '[]'),
#  75: ('```json\n[]\n```', '[]'),
#  77: ('```json\n'
#       '[\n'
#       '    {\n'
#       '        "context_type": "first-party-collection-use",\n'
#       '        "data_entity": "Personal Information about you"\n'
#       '    },\n'
#       '    {\n'
#       '        "context_type": "data-storage-retention-deletion",\n'
#       '        "data_entity": "information we hold about you"\n'
#       '    },\n'
#       '    {\n'
#       '        "context_type": "third-party-sharing-disclosure",\n'
#       '        "data_entity": "information you have provided"\n'
#       '    },\n'
#       '    {\n'
#       '        "context_type": "first-party-collection-use",\n'
#       '        "data_entity": "your Personal Information"\n'
#       '    },\n'
#       '    {\n'
#       '        "context_type": "third-party-sharing-disclosure",\n'
#       '        "data_entity": "information about you"\n'
#       '    }\n'
#       ']\n'
#       '```',
#       '[]'),
#  78: ('```json\n[]\n```', '[]'),
#  80: ('```json\n'
#       '[\n'
#       '    {\n'
#       '        "context_type": "data-storage-retention-deletion",\n'
#       '        "data_entity": "Personal Information"\n'
#       '    },\n'
#       '    {\n'
#       '        "context_type": "data-storage-retention-deletion",\n'
#       '        "data_entity": "Scrapbooks"\n'
#       '    },\n'
#       '    {\n'
#       '        "context_type": "data-storage-retention-deletion",\n'
#       '        "data_entity": "Polos"\n'
#       '    },\n'
#       '    {\n'
#       '        "context_type": "data-storage-retention-deletion",\n'
#       '        "data_entity": "name"\n'
#       '    },\n'
#       '    {\n'
#       '        "context_type": "data-storage-retention-deletion",\n'
#       '        "data_entity": "profile picture"\n'
#       '    },\n'
#       '    {\n'
#       '        "context_type": "data-storage-retention-deletion",\n'
#       '        "data_entity": "messages"\n'
#       '    },\n'
#       '    {\n'
#       '        "context_type": "data-storage-retention-deletion",\n'
#       '        "data_entity": "information you have shared"\n'
#       '    },\n'
#       '    {\n'
#       '        "context_type": "data-storage-retention-deletion",\n'
#       '        "data_entity": "Polo"\n'
#       '    },\n'
#       '    {\n'
#       '        "context_type": "data-storage-retention-deletion",\n'
#       '        "data_entity": "message"\n'
#       '    }\n'
#       ']\n'
#       '```',
#       '["name", "profile picture", "messages", "message"]'),
#  82: ('```json\n'
#       '[\n'
#       '    {\n'
#       '        "context_type": "first-party-collection-use",\n'
#       '        "data_entity": "mobile number"\n'
#       '    },\n'
#       '    {\n'
#       '        "context_type": "first-party-collection-use",\n'
#       '        "data_entity": "name"\n'
#       '    },\n'
#       '    {\n'
#       '        "context_type": "first-party-collection-use",\n'
#       '        "data_entity": "email address"\n'
#       '    },\n'
#       '    {\n'
#       '        "context_type": "first-party-collection-use",\n'
#       '        "data_entity": "photo"\n'
#       '    },\n'
#       '    {\n'
#       '        "context_type": "first-party-collection-use",\n'
#       '        "data_entity": "birth day"\n'
#       '    },\n'
#       '    {\n'
#       '        "context_type": "first-party-collection-use",\n'
#       '        "data_entity": "birth month"\n'
#       '    },\n'
#       '    {\n'
#       '        "context_type": "third-party-sharing-disclosure",\n'
#       '        "data_entity": "name"\n'
#       '    },\n'
#       '    {\n'
#       '        "context_type": "third-party-sharing-disclosure",\n'
#       '        "data_entity": "photo"\n'
#       '    },\n'
#       '    {\n'
#       '        "context_type": "third-party-sharing-disclosure",\n'
#       '        "data_entity": "mobile number"\n'
#       '    },\n'
#       '    {\n'
#       '        "context_type": "third-party-sharing-disclosure",\n'
#       '        "data_entity": "email"\n'
#       '    },\n'
#       '    {\n'
#       '        "context_type": "third-party-sharing-disclosure",\n'
#       '        "data_entity": "birth day"\n'
#       '    },\n'
#       '    {\n'
#       '        "context_type": "third-party-sharing-disclosure",\n'
#       '        "data_entity": "birth month"\n'
#       '    },\n'
#       '    {\n'
#       '        "context_type": "data-security-protection",\n'
#       '        "data_entity": "name"\n'
#       '    },\n'
#       '    {\n'
#       '        "context_type": "data-security-protection",\n'
#       '        "data_entity": "mobile number"\n'
#       '    }\n'
#       ']\n'
#       '```',
#       '["name", "photo", "name", "photo"]'),
#  83: ('```json\n'
#       '[\n'
#       '    {\n'
#       '        "context_type": "first-party-collection-use",\n'
#       '        "data_entity": "videos"\n'
#       '    },\n'
#       '    {\n'
#       '        "context_type": "first-party-collection-use",\n'
#       '        "data_entity": "photos"\n'
#       '    },\n'
#       '    {\n'
#       '        "context_type": "first-party-collection-use",\n'
#       '        "data_entity": "short video clips"\n'
#       '    },\n'
#       '    {\n'
#       '        "context_type": "first-party-collection-use",\n'
#       '        "data_entity": "text messages"\n'
#       '    },\n'
#       '    {\n'
#       '        "context_type": "data-storage-retention-deletion",\n'
#       '        "data_entity": "Personal Information"\n'
#       '    },\n'
#       '    {\n'
#       '        "context_type": "first-party-collection-use",\n'
#       '        "data_entity": "friends\' contact information"\n'
#       '    },\n'
#       '    {\n'
#       '        "context_type": "first-party-collection-use",\n'
#       '        "data_entity": "mobile phone numbers"\n'
#       '    },\n'
#       '    {\n'
#       '        "context_type": "first-party-collection-use",\n'
#       '        "data_entity": "email addresses"\n'
#       '    },\n'
#       '    {\n'
#       '        "context_type": "data-storage-retention-deletion",\n'
#       '        "data_entity": "contacts"\n'
#       '    },\n'
#       '    {\n'
#       '        "context_type": "data-storage-retention-deletion",\n'
#       '        "data_entity": "name"\n'
#       '    },\n'
#       '    {\n'
#       '        "context_type": "data-storage-retention-deletion",\n'
#       '        "data_entity": "phone number(s)"\n'
#       '    },\n'
#       '    {\n'
#       '        "context_type": "data-storage-retention-deletion",\n'
#       '        "data_entity": "email address(es)"\n'
#       '    },\n'
#       '    {\n'
#       '        "context_type": "data-storage-retention-deletion",\n'
#       '        "data_entity": "birth day and month"\n'
#       '    }\n'
#       ']\n'
#       '```',
#       '["contacts", "name", "contacts", "photos", "friends\' contact '
#       'information"]'),
#  84: ('```json\n'
#       '[\n'
#       '    {\n'
#       '        "context": "first-party-collection-use",\n'
#       '        "data_entity": "Personal Information"\n'
#       '    }\n'
#       ']\n'
#       '```',
#       '[]'),
#  85: ('```json\n'
#       '[\n'
#       '    {\n'
#       '        "context_type": "third-party-collection-use",\n'
#       '        "text": "operating system type"\n'
#       '    },\n'
#       '    {\n'
#       '        "context_type": "third-party-collection-use",\n'
#       '        "text": "browser type"\n'
#       '    },\n'
#       '    {\n'
#       '        "context_type": "third-party-collection-use",\n'
#       '        "text": "language"\n'
#       '    },\n'
#       '    {\n'
#       '        "context_type": "third-party-collection-use",\n'
#       '        "text": "pages you viewed"\n'
#       '    },\n'
#       '    {\n'
#       '        "context_type": "third-party-collection-use",\n'
#       '        "text": "how long you spent on a page"\n'
#       '    },\n'
#       '    {\n'
#       '        "context_type": "third-party-collection-use",\n'
#       '        "text": "access times"\n'
#       '    },\n'
#       '    {\n'
#       '        "context_type": "third-party-collection-use",\n'
#       '        "text": "Internet protocol (IP) address"\n'
#       '    },\n'
#       '    {\n'
#       '        "context_type": "third-party-collection-use",\n'
#       '        "text": "mobile device ID"\n'
#       '    },\n'
#       '    {\n'
#       '        "context_type": "third-party-collection-use",\n'
#       '        "text": "mobile device serial number"\n'
#       '    },\n'
#       '    {\n'
#       '        "context_type": "third-party-collection-use",\n'
#       '        "text": "unique user ID"\n'
#       '    },\n'
#       '    {\n'
#       '        "context_type": "third-party-collection-use",\n'
#       '        "text": "wireless carrier"\n'
#       '    },\n'
#       '    {\n'
#       '        "context_type": "third-party-collection-use",\n'
#       '        "text": "information about your use of and actions on the '
#       'Service"\n'
#       '    }\n'
#       ']\n'
#       '```',
#       '["browser type and\\u200e language", "unique user ID", "wireless '
#       'carrier"]'),
#  86: ('```json\n[]\n```', '[]'),
#  87: ('```json\n[]\n```', '[]'),
#  93: ('```json\n'
#       '[\n'
#       '    {\n'
#       '        "type": "third-party-sharing-disclosure",\n'
#       '        "text": "Codecademy user data and metadata"\n'
#       '    },\n'
#       '    {\n'
#       '        "type": "third-party-collection-use",\n'
#       '        "text": "user related information"\n'
#       '    }\n'
#       ']\n'
#       '```',
#       '[]'),
#  94: ('```json\n[]\n```', '["contact information"]'),
#  95: ('```json\n[]\n```', '[]'),
#  100: ('```json\n'
#        '[\n'
#        '    {\n'
#        '        "context_type": "first-party-collection-use",\n'
#        '        "text": "username"\n'
#        '    },\n'
#        '    {\n'
#        '        "context_type": "first-party-collection-use",\n'
#        '        "text": "email address"\n'
#        '    },\n'
#        '    {\n'
#        '        "context_type": "first-party-collection-use",\n'
#        '        "text": "password"\n'
#        '    },\n'
#        '    {\n'
#        '        "context_type": "first-party-collection-use",\n'
#        '        "text": "name"\n'
#        '    },\n'
#        '    {\n'
#        '        "context_type": "first-party-collection-use",\n'
#        '        "text": "location"\n'
#        '    },\n'
#        '    {\n'
#        '        "context_type": "first-party-collection-use",\n'
#        '        "text": "website"\n'
#        '    },\n'
#        '    {\n'
#        '        "context_type": "first-party-collection-use",\n'
#        '        "text": "links to your social media profiles"\n'
#        '    },\n'
#        '    {\n'
#        '        "context_type": "first-party-collection-use",\n'
#        '        "text": "User Content"\n'
#        '    },\n'
#        '    {\n'
#        '        "context_type": "first-party-collection-use",\n'
#        '        "text": "messages"\n'
#        '    },\n'
#        '    {\n'
#        '        "context_type": "first-party-collection-use",\n'
#        '        "text": "email messages"\n'
#        '    }\n'
#        ']\n'
#        '```',
#        '["username", "password", "name", "location", "messages"]'),
#  101: ('```json\n[]\n```',
#        '["user ID", "an access token necessary to access that service", "your '
#        'friends\' user IDs", "your connection to those friends", "Facebook '
#        'UID"]'),
#  102: ('```json\n[]\n```',
#        '["geographical location data", "similar information regarding the '
#        'location of your mobile device", "location data", "web request", '
#        '"browser type", "referring / exit pages and URLs", "domain names", '
#        '"landing pages"]'),
#  103: ('```json\n[]\n```', '[]'),
#  104: ('```json\n'
#        '[\n'
#        '    {\n'
#        '        "context_type": "third-party-sharing-disclosure",\n'
#        '        "data_entity_text": "your personal information with other '
#        'companies owned by or under common ownership as Codecademy"\n'
#        '    },\n'
#        '    {\n'
#        '        "context_type": "third-party-sharing-disclosure",\n'
#        '        "data_entity_text": "your personal information with third '
#        'party vendors, consultants, contractors and other service providers"\n'
#        '    },\n'
#        '    {\n'
#        '        "context_type": "third-party-sharing-disclosure",\n'
#        '        "data_entity_text": "your information shared with third party '
#        'social networks"\n'
#        '    },\n'
#        '    {\n'
#        '        "context_type": "third-party-sharing-disclosure",\n'
#        '        "data_entity_text": "your information, such as user names and '
#        'email addresses, User Content and other user information"\n'
#        '    },\n'
#        '    {\n'
#        '        "context_type": "third-party-sharing-disclosure",\n'
#        '        "data_entity_text": "your information, such as user names and '
#        'email addresses"\n'
#        '    },\n'
#        '    {\n'
#        '        "context_type": "third-party-sharing-disclosure",\n'
#        '        "data_entity_text": "your information shared as reasonably '
#        'necessary to satisfy any applicable law, regulation, subpoena/court '
#        'order, legal process or other government request"\n'
#        '    }\n'
#        ']\n'
#        '```',
#        '["user names"]'),
#  105: ('```json\n'
#        '[\n'
#        '    {\n'
#        '        "context_type": "data-storage-retention-deletion",\n'
#        '        "text": "We will retain your information for as long as your '
#        'account is active or as needed to provide you services."\n'
#        '    },\n'
#        '    {\n'
#        '        "context_type": "data-storage-retention-deletion",\n'
#        '        "text": "we will maintain your personal information in the '
#        'event you wish to re-engage in our Service."\n'
#        '    },\n'
#        '    {\n'
#        '        "context_type": "data-storage-retention-deletion",\n'
#        '        "text": "You may delete your account by visiting the \'My '
#        'Account\' page."\n'
#        '    }\n'
#        ']\n'
#        '```',
#        '[]'),
#  106: ('```json\n'
#        '[\n'
#        '    {\n'
#        '        "context": "first-party-collection-use",\n'
#        '        "data_entity": "your personal data"\n'
#        '    },\n'
#        '    {\n'
#        '        "context": "third-party-collection-use",\n'
#        '        "data_entity": "personal data"\n'
#        '    },\n'
#        '    {\n'
#        '        "context": "data-storage-retention-deletion",\n'
#        '        "data_entity": "your personal data"\n'
#        '    },\n'
#        '    {\n'
#        '        "context": "data-storage-retention-deletion",\n'
#        '        "data_entity": "personal data"\n'
#        '    },\n'
#        '    {\n'
#        '        "context": "data-security-protection",\n'
#        '        "data_entity": "your personal data"\n'
#        '    },\n'
#        '    {\n'
#        '        "context": "data-security-protection",\n'
#        '        "data_entity": "personal data"\n'
#        '    }\n'
#        ']\n'
#        '```',
#        '[]'),
#  107: ('```json\n'
#        '[\n'
#        '    {\n'
#        '        "context": "data-storage-retention-deletion",\n'
#        '        "text": "information collected through the Service may be '
#        'stored and processed in the United States or any other country in '
#        'which Codecademy or its subsidiaries, affiliates or service providers '
#        'maintain facilities"\n'
#        '    },\n'
#        '    {\n'
#        '        "context": "third-party-sharing-disclosure",\n'
#        '        "text": "Codecademy may transfer information that we collect '
#        'about you, including personal information, to affiliated entities, or '
#        'to other third parties across borders"\n'
#        '    },\n'
#        '    {\n'
#        '        "context": "data-security-protection",\n'
#        '        "text": "Codecademy cares about the security of your '
#        'information and uses commercially reasonable safeguards to preserve '
#        'the integrity and security of all information collected through the '
#        'Service"\n'
#        '    },\n'
#        '    {\n'
#        '        "context": "data-security-protection",\n'
#        '        "text": "in the event that any information under our control '
#        'is compromised as a result of a breach of security, we will take '
#        'reasonable steps to investigate the situation"\n'
#        '    }\n'
#        ']\n'
#        '```',
#        '[]'),
#  111: ('```json\n'
#        '[\n'
#        '    {\n'
#        '        "context_type": "first-party-collection-use",\n'
#        '        "text": "first and last name"\n'
#        '    },\n'
#        '    {\n'
#        '        "context_type": "first-party-collection-use",\n'
#        '        "text": "home address"\n'
#        '    },\n'
#        '    {\n'
#        '        "context_type": "first-party-collection-use",\n'
#        '        "text": "email address"\n'
#        '    },\n'
#        '    {\n'
#        '        "context_type": "first-party-collection-use",\n'
#        '        "text": "driving behavior while using our Service"\n'
#        '    },\n'
#        '    {\n'
#        '        "context_type": "first-party-collection-use",\n'
#        '        "text": "vehicle information"\n'
#        '    },\n'
#        '    {\n'
#        '        "context_type": "first-party-collection-use",\n'
#        '        "text": "on-board diagnostics information"\n'
#        '    },\n'
#        '    {\n'
#        '        "context_type": "first-party-collection-use",\n'
#        '        "text": "geo-location information"\n'
#        '    },\n'
#        '    {\n'
#        '        "context_type": "first-party-collection-use",\n'
#        '        "text": "IP address"\n'
#        '    },\n'
#        '    {\n'
#        '        "context_type": "third-party-collection-use",\n'
#        '        "text": "information from your third party service account"\n'
#        '    },\n'
#        '    {\n'
#        '        "context_type": "third-party-sharing-disclosure",\n'
#        '        "text": "information is collected by the third party service '
#        'provider and is provided to Navdy"\n'
#        '    }\n'
#        ']\n'
#        '```',
#        '["first and last name", "vehicle information", "on-board diagnostics '
#        'information", "browser type and version", "standard web log '
#        'information"]'),
#  112: ('```json\n[]\n```',
#        '["browser type", "preferences", "data relating to content that has '
#        'been displayed to you or that you have clicked on", "usage data", '
#        '"information that could be used to identify you or your mobile '
#        'device"]'),
#  113: ('```json\n[]\n```', '[]'),
#  114: ('```json\n'
#        '[\n'
#        '    {\n'
#        '        "context_type": "third-party-sharing-disclosure",\n'
#        '        "data_entity": "Personally Identifiable Information"\n'
#        '    },\n'
#        '    {\n'
#        '        "context_type": "third-party-sharing-disclosure",\n'
#        '        "data_entity": "first name"\n'
#        '    },\n'
#        '    {\n'
#        '        "context_type": "third-party-sharing-disclosure",\n'
#        '        "data_entity": "last name"\n'
#        '    },\n'
#        '    {\n'
#        '        "context_type": "third-party-sharing-disclosure",\n'
#        '        "data_entity": "company name"\n'
#        '    },\n'
#        '    {\n'
#        '        "context_type": "third-party-sharing-disclosure",\n'
#        '        "data_entity": "mailing address"\n'
#        '    },\n'
#        '    {\n'
#        '        "context_type": "third-party-sharing-disclosure",\n'
#        '        "data_entity": "phone number"\n'
#        '    },\n'
#        '    {\n'
#        '        "context_type": "third-party-sharing-disclosure",\n'
#        '        "data_entity": "email address"\n'
#        '    },\n'
#        '    {\n'
#        '        "context_type": "third-party-sharing-disclosure",\n'
#        '        "data_entity": "credit card payment information"\n'
#        '    },\n'
#        '    {\n'
#        '        "context_type": "third-party-sharing-disclosure",\n'
#        '        "data_entity": "account information"\n'
#        '    },\n'
#        '    {\n'
#        '        "context_type": "third-party-sharing-disclosure",\n'
#        '        "data_entity": "device information"\n'
#        '    },\n'
#        '    {\n'
#        '        "context_type": "third-party-sharing-disclosure",\n'
#        '        "data_entity": "location"\n'
#        '    },\n'
#        '    {\n'
#        '        "context_type": "third-party-sharing-disclosure",\n'
#        '        "data_entity": "logs and reports from your Navdy Device"\n'
#        '    },\n'
#        '    {\n'
#        '        "context_type": "third-party-sharing-disclosure",\n'
#        '        "data_entity": "information relating to visitors and users of '
#        'our Service"\n'
#        '    },\n'
#        '    {\n'
#        '        "context_type": "third-party-sharing-disclosure",\n'
#        '        "data_entity": "personal data"\n'
#        '    },\n'
#        '    {\n'
#        '        "context_type": "third-party-sharing-disclosure",\n'
#        '        "data_entity": "any information"\n'
#        '    }\n'
#        ']\n'
#        '```',
#        '["first name", "last name", "location"]'),
#  116: ('```json\n'
#        '[\n'
#        '    {\n'
#        '        "context": "third-party-collection-use",\n'
#        '        "text": "personally identifiable information about your online '
#        'activities over time and across different websites"\n'
#        '    }\n'
#        ']\n'
#        '```',
#        '["personally identifiable information"]'),
#  118: ('```json\n'
#        '[\n'
#        '    {\n'
# ...
#        '    },\n'
#        '    {\n'
#        '        "context_type": "third-party-sharing-disclosure",\n'
#        '        "data_entity": "your personal data"\n'
#        '    },\n'
#        '    {\n'
#        '        "context_type": "third-party-sharing-disclosure",\n'
#        '        "data_entity": "your personal data"\n'
#        '    }\n'
#        ']\n'
#        '```',
#        '[]'),
#  127: ('```json\n'
#        '[\n'
#        '    {\n'
#        '        "context_type": "first-party-collection-use",\n'
#        '        "data_entity": "your personal data"\n'
#        '    },\n'
#        '    {\n'
#        '        "context_type": "first-party-collection-use",\n'
#        '        "data_entity": "your personal data for direct marketing '
#        'purposes"\n'
#        '    },\n'
#        '    {\n'
#        '        "context_type": "first-party-collection-use",\n'
#        '        "data_entity": "your personal data for customizing or '
#        'personalizing ads, offers and content"\n'
#        '    },\n'
#        '    {\n'
#        '        "context_type": "first-party-collection-use",\n'
#        '        "data_entity": "information we have about you"\n'
#        '    },\n'
#        '    {\n'
#        '        "context_type": "third-party-collection-use",\n'
#        '        "data_entity": "third party products and services"\n'
#        '    },\n'
#        '    {\n'
#        '        "context_type": "third-party-collection-use",\n'
#        '        "data_entity": "third party services"\n'
#        '    },\n'
#        '    {\n'
#        '        "context_type": "third-party-sharing-disclosure",\n'
#        '        "data_entity": "relevant announcements"\n'
#        '    }\n'
#        ']\n'
#        '```',
#        '[]'),
#  128: ('```json\n'
#        '[\n'
#        '    {\n'
#        '        "context": "third-party-sharing-disclosure",\n'
#        '        "data_entity": "personal data"\n'
#        '    },\n'
#        '    {\n'
#        '        "context": "third-party-sharing-disclosure",\n'
#        '        "data_entity": "personal data"\n'
#        '    },\n'
#        '    {\n'
#        '        "context": "third-party-sharing-disclosure",\n'
#        '        "data_entity": "personal data"\n'
#        '    },\n'
#        '    {\n'
#        '        "context": "data-security-protection",\n'
#        '        "data_entity": "personal data"\n'
#        '    },\n'
#        '    {\n'
#        '        "context": "data-security-protection",\n'
#        '        "data_entity": "personal data"\n'
#        '    }\n'
#        ']\n'
#        '```',
#        '[]'),
#  129: ('```json\n[]\n```', '[]'),
#  130: ('```json\n'
#        '[\n'
#        '    {\n'
#        '        "context_type": "data-storage-retention-deletion",\n'
#        '        "data_entity": "your personal data"\n'
#        '    },\n'
#        '    {\n'
#        '        "context_type": "data-storage-retention-deletion",\n'
#        '        "data_entity": "your personal data"\n'
#        '    },\n'
#        '    {\n'
#        '        "context_type": "data-storage-retention-deletion",\n'
#        '        "data_entity": "your personal data"\n'
#        '    },\n'
#        '    {\n'
#        '        "context_type": "data-storage-retention-deletion",\n'
#        '        "data_entity": "your personal data"\n'
#        '    }\n'
#        ']\n'
#        '```',
#        '[]'),
#  133: ('```json\n[]\n```', '[]'),
#  134: ('```json\n[]\n```', '[]'),
#  135: ('```json\n[]\n```', '[]'),
#  136: ('```json\n[]\n```', '[]'),
#  137: ('```json\n[]\n```', '[]'),
#  139: ('```json\n[]\n```', '[]'),
#  140: ('```json\n'
#        '[\n'
#        '    {\n'
#        '        "context_type": "data-security-protection",\n'
#        '        "data_entity": "personal data that we hold"\n'
#        '    },\n'
#        '    {\n'
#        '        "context_type": "data-security-protection",\n'
#        '        "data_entity": "personal data"\n'
#        '    },\n'
#        '    {\n'
#        '        "context_type": "data-security-protection",\n'
#        '        "data_entity": "personal contact"\n'
#        '    },\n'
#        '    {\n'
#        '        "context_type": "data-security-protection",\n'
#        '        "data_entity": "geographic location"\n'
#        '    },\n'
#        '    {\n'
#        '        "context_type": "data-security-protection",\n'
#        '        "data_entity": "sensitive personal data"\n'
#        '    },\n'
#        '    {\n'
#        '        "context_type": "data-security-protection",\n'
#        '        "data_entity": "your personal data"\n'
#        '    },\n'
#        '    {\n'
#        '        "context_type": "data-storage-retention-deletion",\n'
#        '        "data_entity": "information you provided"\n'
#        '    },\n'
#        '    {\n'
#        '        "context_type": "thrid-party-sharing-disclosure",\n'
#        '        "data_entity": "information and data collected"\n'
#        '    }\n'
#        ']\n'
#        '```',
#        '[]'),
#  141: ('```json\n[]\n```', '["log information"]'),
#  142: ('```json\n'
#        '[\n'
#        '    {\n'
#        '        "context_type": "first-party-collection-use",\n'
#        '        "data_entity": "email address"\n'
#        '    },\n'
#        '    {\n'
#        '        "context_type": "first-party-collection-use",\n'
#        '        "data_entity": "contact information"\n'
#        '    }\n'
#        ']\n'
#        '```',
#        '["contact information"]'),
#  143: ('```json\n[]\n```', '[]'),
#  145: ('```json\n[]\n```', '[]'),
#  147: ('```json\n'
#        '[\n'
#        '    {\n'
#        '        "context_type": "first-party-collection-use",\n'
#        '        "data_entity": "location information"\n'
#        '    },\n'
#        '    {\n'
#        '        "context_type": "first-party-collection-use",\n'
#        '        "data_entity": "actual location"\n'
#        '    },\n'
#        '    {\n'
#        '        "context_type": "first-party-collection-use",\n'
#        '        "data_entity": "IP address"\n'
#        '    },\n'
#        '    {\n'
#        '        "context_type": "first-party-collection-use",\n'
#        '        "data_entity": "GPS"\n'
#        '    }\n'
#        ']\n'
#        '```',
#        '["information about your actual location", "location information"]'),
#  148: ('```json\n'
#        '[\n'
#        '    {\n'
#        '        "context_type": "first-party-collection-use",\n'
#        '        "text": "a valid email address as the “recovery email”"\n'
#        '    },\n'
#        '    {\n'
#        '        "context_type": "third-party-sharing-disclosure",\n'
#        '        "text": "recovery email"\n'
#        '    }\n'
#        ']\n'
#        '```',
#        '[]'),
#  149: ('```json\n[]\n```', '[]'),
#  152: ('```json\n[]\n```', '[]'),
#  153: ('```json\n[]\n```', '[]'),
#  154: ('```json\n'
#        '[\n'
#        '    {\n'
#        '        "context_type": "third-party-sharing-disclosure",\n'
#        '        "data_entity": "personal information"\n'
#        '    },\n'
#        '    {\n'
#        '        "context_type": "third-party-sharing-disclosure",\n'
#        '        "data_entity": "any personal information about you"\n'
#        '    },\n'
#        '    {\n'
#        '        "context_type": "data-security-protection",\n'
#        '        "data_entity": "your personal information"\n'
#        '    },\n'
#        '    {\n'
#        '        "context_type": "data-security-protection",\n'
#        '        "data_entity": "your personal information"\n'
#        '    }\n'
#        ']\n'
#        '```',
#        '[]'),
#  155: ('```json\n'
#        '[\n'
#        '    {\n'
#        '        "context_type": "data-security-protection",\n'
#        '        "text": "personal information"\n'
#        '    },\n'
#        '    {\n'
#        '        "context_type": "data-security-protection",\n'
#        '        "text": "personal information"\n'
#        '    },\n'
#        '    {\n'
#        '        "context_type": "data-security-protection",\n'
#        '        "text": "personal information"\n'
#        '    },\n'
#        '    {\n'
#        '        "context_type": "data-security-protection",\n'
#        '        "text": "personal information"\n'
#        '    },\n'
#        '    {\n'
#        '        "context_type": "data-security-protection",\n'
#        '        "text": "email address"\n'
#        '    },\n'
#        '    {\n'
#        '        "context_type": "data-security-protection",\n'
#        '        "text": "data"\n'
#        '    },\n'
#        '    {\n'
#        '        "context_type": "data-security-protection",\n'
#        '        "text": "personal information"\n'
#        '    },\n'
#        '    {\n'
#        '        "context_type": "data-storage-retention-deletion",\n'
#        '        "text": "personal information"\n'
#        '    }\n'
#        ']\n'
#        '```',
#        '[]'),
#  158: ('```json\n'
#        '[\n'
#        '    {\n'
#        '        "context_type": "first-party-collection-use",\n'
#        '        "data_entity": "data about your general location"\n'
#        '    },\n'
#        '    {\n'
#        '        "context_type": "first-party-collection-use",\n'
#        '        "data_entity": "Identifier for Advertising (IDFA)"\n'
#        '    },\n'
#        '    {\n'
#        '        "context_type": "first-party-collection-use",\n'
#        '        "data_entity": "your handle"\n'
#        '    },\n'
#        '    {\n'
#        '        "context_type": "first-party-collection-use",\n'
#        '        "data_entity": "any data that you share within your messages '
#        'posted to that chat"\n'
#        '    },\n'
#        '    {\n'
#        '        "context_type": "first-party-collection-use",\n'
#        '        "data_entity": "your basic Facebook profile information"\n'
#        '    },\n'
#        '    {\n'
#        '        "context_type": "first-party-collection-use",\n'
#        '        "data_entity": "your e-mail address"\n'
#        '    }\n'
#        ']\n'
#        '```',
#        '["data about your general location"]'),
#  159: ('```json\n'
#        '[\n'
#        '    {\n'
#        '        "type": "first-party-collection-use",\n'
#        '        "text": "personal information"\n'
#        '    },\n'
#        '    {\n'
#        '        "type": "third-party-collection-use",\n'
#        '        "text": "personal information"\n'
#        '    },\n'
#        '    {\n'
#        '        "type": "data-storage-retention-deletion",\n'
#        '        "text": "personal information"\n'
#        '    },\n'
#        '    {\n'
#        '        "type": "first-party-collection-use",\n'
#        '        "text": "advertising and marketing"\n'
#        '    },\n'
#        '    {\n'
#        '        "type": "third-party-sharing-disclosure",\n'
#        '        "text": "advertising and marketing"\n'
#        '    },\n'
#        '    {\n'
#        '        "type": "first-party-collection-use",\n'
#        '        "text": "preferences in relation to advertising and marketing '
#        'communications"\n'
#        '    },\n'
#        '    {\n'
#        '        "type": "first-party-collection-use",\n'
#        '        "text": "customer support enquiries"\n'
#        '    }\n'
#        ']\n'
#        '```',
#        '[]'),
#  160: ('```json\n[]\n```', '[]'),
#  164: ('```json\n'
#        '[\n'
#        '    {\n'
#        '        "context_type": "third-party-collection-use",\n'
#        '        "text": "data about your device, location and use of our apps, '
#        'including IP address, a unique device ID, geo-location details and '
#        'your User ID that we have assigned to you"\n'
#        '    },\n'
#        '    {\n'
#        '        "context_type": "third-party-collection-use",\n'
#        '        "text": "data which you provide to us when using our apps, '
#        'including information on your interaction with advertising and certain '
#        'technical information"\n'
#        '    },\n'
#        '    {\n'
#        '        "context_type": "third-party-sharing-disclosure",\n'
#        '        "text": "your IDFA with Facebook"\n'
#        '    }\n'
#        ']\n'
#        '```',
#        '["location", "User ID"]'),
#  165: ('```json\n'
#        '[\n'
#        '    {\n'
#        '        "context_type": "third-party-sharing-disclosure",\n'
#        '        "text": "your personal information"\n'
#        '    },\n'
#        '    {\n'
#        '        "context_type": "third-party-sharing-disclosure",\n'
#        '        "text": "personal data"\n'
#        '    },\n'
#        '    {\n'
#        '        "context_type": "third-party-sharing-disclosure",\n'
#        '        "text": "your personal information"\n'
#        '    },\n'
#        '    {\n'
#        '        "context_type": "third-party-sharing-disclosure",\n'
#        '        "text": "your personal information"\n'
#        '    },\n'
#        '    {\n'
#        '        "context_type": "third-party-sharing-disclosure",\n'
#        '        "text": "personal information"\n'
#        '    },\n'
#        '    {\n'
#        '        "context_type": "third-party-sharing-disclosure",\n'
#        '        "text": "your personal information"\n'
#        '    },\n'
#        '    {\n'
#        '        "context_type": "third-party-sharing-disclosure",\n'
#        '        "text": "your personal information"\n'
#        '    },\n'
#        '    {\n'
#        '        "context_type": "third-party-sharing-disclosure",\n'
#        '        "text": "your personal information"\n'
#        '    }\n'
#        ']\n'
#        '```',
#        '[]'),
#  166: ('```json\n[]\n```', '[]'),
#  167: ('```json\n[]\n```',
#        '["name", "purchase information", "the dates of purchase", "the '
#        'purchase price", "browser type", "browser language", "information '
#        'about your user preferences", "location"]'),
#  168: ('```json\n[]\n```', '[]'),
#  169: ('```json\n[]\n```', '[]'),
#  170: ('```json\n'
#        '[\n'
#        '    {\n'
#        '        "context_type": "third-party-sharing-disclosure",\n'
#        '        "data_entity": "personal information collected online"\n'
#        '    }\n'
#        ']\n'
#        '```',
#        '[]'),
#  173: ('```json\n'
#        '[\n'
#        '    {\n'
#        '        "context_type": "first-party-collection-use",\n'
#        '        "text": "certain personal information such as email address, '
#        'zip code, telephone number, and in some instances information about '
#        'your business"\n'
#        '    },\n'
#        '    {\n'
#        '        "context_type": "first-party-collection-use",\n'
#        '        "text": "titles purchased, quantity and dates of purchases, '
#        'the method of payment, and other information provided such as billing '
#        'and shipping addresses"\n'
#        '    },\n'
#        '    {\n'
#        '        "context_type": "data-storage-retention-deletion",\n'
#        '        "text": "We will keep these records for a period of no more '
#        'than 6 years"\n'
#        '    },\n'
#        '    {\n'
#        '        "context_type": "first-party-collection-use",\n'
#        '        "text": "email address"\n'
#        '    },\n'
#        '    {\n'
#        '        "context_type": "third-party-sharing-disclosure",\n'
#        '        "text": "information you provide is maintained"\n'
#        '    }\n'
#        ']\n'
#        '```',
#        '["titles purchased", "quantity and dates of purchases", "method of '
#        'payment", "name you provide for your EMI Profile", "past names '
#        'associated with your EMI Account", "a record of your communications"]'),
#  174: ('```json\n[]\n```', '[]'),
#  177: ('```json\n[]\n```', '[]'),
#  179: ('```json\n'
#        '[\n'
#        '    {\n'
#        '        "context_type": "data-storage-retention-deletion",\n'
#        '        "text": "we have to keep that information for legitimate '
#        'business or legal purposes, in which case it will be retained for the '
#        'periods specified in this Privacy Policy"\n'
#        '    },\n'
#        '    {\n'
#        '        "context_type": "data-storage-retention-deletion",\n'
#        '        "text": "after you delete information from our Service, we may '
#        'not immediately delete residual copies from our active servers and may '
#        'not remove information from our backup systems"\n'
#        '    },\n'
#        '    {\n'
#        '        "context_type": "first-party-collection-use",\n'
#        '        "text": "we may ask you to verify your identity before we can '
#        'act on your request"\n'
#        '    }\n'
#        ']\n'
#        '```',
#        '[]'),
#  180: ('```json\n[]\n```', '[]')}

# %%
# For query '2024-09-13-00-44-00-6cbf289f-798c-46ff-8d72-221b0da1099e'
# For model 'ft:gpt-4o-mini-2024-07-18:rui:30-train-5-val-content-only-from-api:A6cig7w6'
# print(np.mean(result_score_list, axis=0))
print(f"{len(result_score_list)} valid datapoints, avg. precission, recall, f1:", np.mean(result_score_list, axis=0))
print(f"{len(non_empty_result_score_list)} (ought to be) non-empty datapoints, avg. precission, recall, f1:", np.mean(non_empty_result_score_list, axis=0))
print(f"{len(empty_result_score_list)} (ought to be) empty datapoints, avg. precission, recall, f1:", np.mean(empty_result_score_list, axis=0))
print(f"{len(failed)} datapoints are not valid JSON")
failed
# Out:
# 146 valid datapoints, avg. precission, recall, f1: [0.02842466 0.02796804 0.02663079]
# 10 (ought to be) non-empty datapoints, avg. precission, recall, f1: [0.415      0.40833333 0.38880952]
# 136 (ought to be) empty datapoints, avg. precission, recall, f1: [0. 0. 0.]
# 0 datapoints are not valid JSON
# {}

# %%
# For query '2024-09-13-11-25-49-a393b3ea-6ae0-4433-8e92-610bd63e1305'
# For model 'ft:gpt-4o-mini-2024-07-18:rui:30-train-5-val-with-empty-from-api:A6o1jAxy'

print(f"{len(result_score_list)} valid datapoints, avg. precission, recall, f1:", np.mean(result_score_list, axis=0))
print(f"{len(non_empty_result_score_list)} (ought to be) non-empty datapoints, avg. precission, recall, f1:", np.mean(non_empty_result_score_list, axis=0))
print(f"{len(empty_result_score_list)} (ought to be) empty datapoints, avg. precission, recall, f1:", np.mean(empty_result_score_list, axis=0))
print(f"{len(failed)} datapoints are not valid JSON")
failed
# Out:
# 144 valid datapoints, avg. precission, recall, f1: [0.78908855 0.80578704 0.78842856]
# 21 (ought to be) non-empty datapoints, avg. precission, recall, f1: [0.2680358  0.38253968 0.26351015]
# 123 (ought to be) empty datapoints, avg. precission, recall, f1: [0.87804878 0.87804878 0.87804878]
# 2 datapoints are not valid JSON
# {54: ('[] reflections of persona data entities []', '[]'),
#  67: ('["name": "Device ID", "type": "identification numbers associated with your device", "type": "personal information"]',
#   '["geographical location data", "similar information regarding the location of your mobile device", "location data", "web request", "browser type", "referring / exit pages and URLs", "domain names", "landing pages"]')}

# %%
def compare_two_evaluations(eval1, eval2):
    desc1, saved_queries1 = eval1
    desc2, saved_queries2 = eval2

    def to_reserve_map(saved_queries):
        reverse_map = {}
        for query in saved_queries:
            key = (str(query['input'][1]), str(query['correct_output']))
            reverse_map[key] = query
        return reverse_map

    reverse_map1 = to_reserve_map(saved_queries1)
    reverse_map2 = to_reserve_map(saved_queries2)

    ## Calculate what keys are common, and what keys are unique to each
    common_keys = set(reverse_map1.keys()) & set(reverse_map2.keys())
    unique_keys1 = set(reverse_map1.keys()) - set(reverse_map2.keys())
    unique_keys2 = set(reverse_map2.keys()) - set(reverse_map1.keys())

    print(len(common_keys), len(unique_keys1), len(unique_keys2))

    # Return the common and unique queries
    common_queries1 = []
    common_queries2 = []
    unique_queries1 = []
    unique_queries2 = []
    for key in common_keys:
        common_queries1.append(reverse_map1[key])
        common_queries2.append(reverse_map2[key])
    for key in unique_keys1:
        unique_queries1.append(reverse_map1[key])
    for key in unique_keys2:
        unique_queries2.append(reverse_map2[key])

    return common_queries1, common_queries2, unique_queries1, unique_queries2


queries_to_load = [
    # '2024-09-13-00-44-00-6cbf289f-798c-46ff-8d72-221b0da1099e',
    '2024-09-13-11-25-49-a393b3ea-6ae0-4433-8e92-610bd63e1305',
    '2024-09-13-14-48-28-ft:gpt-4o-mini-2024-07-18:rui:30-train-5-val-no-empty-from-api:A70TvfoL',
]
eval1, eval2 = [llm_utils.load_saved_llm_queries(query) for query in queries_to_load[:2]]
common_queries1, common_queries2, unique_queries1, unique_queries2 = compare_two_evaluations(eval1, eval2)


calc_and_print_statistics(eval1[0], common_queries1)
calc_and_print_statistics(eval2[0], common_queries2)
calc_and_print_statistics(eval1[0], unique_queries1)
calc_and_print_statistics(eval2[0], unique_queries2)
# Out:
# 134 12 12
# Stat for eval with desc: {'model': 'ft:gpt-4o-mini-2024-07-18:rui:30-train-5-val-with-empty-from-api:A6o1jAxy'}
#   133 valid datapoints, avg. precission, recall, f1: [0.81938179 0.8245614  0.82119585]
#   10 (ought to be) non-empty datapoints, avg. precission, recall, f1: [0.09777778 0.16666667 0.12190476]
#   123 (ought to be) empty datapoints, avg. precission, recall, f1: [0.87804878 0.87804878 0.87804878]
#   1 datapoints are not valid JSON
#   {53: ('[] reflections of persona data entities []', '[]')}
# Stat for eval with desc: {'model': 'ft:gpt-4o-mini-2024-07-18:rui:30-train-5-val-no-empty-from-api:A70TvfoL'}
#   134 valid datapoints, avg. precission, recall, f1: [0.02860697 0.03358209 0.03059701]
#   10 (ought to be) non-empty datapoints, avg. precission, recall, f1: [0.38333333 0.45       0.41      ]
#   124 (ought to be) empty datapoints, avg. precission, recall, f1: [0. 0. 0.]
#   0 datapoints are not valid JSON
#   {}
# Stat for eval with desc: {'model': 'ft:gpt-4o-mini-2024-07-18:rui:30-train-5-val-with-empty-from-api:A6o1jAxy'}
#   11 valid datapoints, avg. precission, recall, f1: [0.42281582 0.57878788 0.39224232]
#   11 (ought to be) non-empty datapoints, avg. precission, recall, f1: [0.42281582 0.57878788 0.39224232]
#   0 (ought to be) empty datapoints, avg. precission, recall, f1: nan
#   1 datapoints are not valid JSON
#   {11: ('["name": "Device ID", "type": "identification numbers associated with '
#       'your device", "type": "personal information"]',
#       '["geographical location data", "similar information regarding the '
#       'location of your mobile device", "location data", "web request", '
#       '"browser type", "referring / exit pages and URLs", "domain names", '
#       '"landing pages"]')}
# Stat for eval with desc: {'model': 'ft:gpt-4o-mini-2024-07-18:rui:30-train-5-val-no-empty-from-api:A70TvfoL'}
#   12 valid datapoints, avg. precission, recall, f1: [0. 0. 0.]
#   0 (ought to be) non-empty datapoints, avg. precission, recall, f1: nan
#   12 (ought to be) empty datapoints, avg. precission, recall, f1: [0. 0. 0.]
#   0 datapoints are not valid JSON
#   {}

# %%
# %debug
# Out:
# > /usr/lib/python3.12/json/decoder.py(340)decode()
#     338         end = _w(s, end).end()
#     339         if end != len(s):
# --> 340             raise JSONDecodeError("Extra data", s, end)
#     341         return obj
#     342
#
# '[] reflections of persona data entities []'
# '[] reflections of persona data entities []'
# '[] reflections of persona data entities []'
# '[] reflections of persona data entities []'

# %% [markdown]
# ## Test code

# %%
# Test how function calls works for normal conversation, beforing turing that into training data.

from openai import OpenAI


assistant = client.beta.assistants.create(
  name="Financial Analyst Assistant",
  instructions="You are an legal annotation expert. Use you knowledge base to answer questions about privacy policies.",
  model="gpt-4o",
  tools=[{"type": "file_search"}],
)


def upload_doc():
    vector_store = client.beta.vector_stores.get(name="Data Categories")

    # Ready the files for upload to OpenAI
    file_paths = [DATA_DEF_FILE]
    file_streams = [open(path, "rb") for path in file_paths]

    # Use the upload and poll SDK helper to upload the files, add them to the vector store,
    # and poll the status of the file batch for completion.
    file_batch = client.beta.vector_stores.file_batches.upload_and_poll(
    vector_store_id=vector_store.id, files=file_streams
    )
    return file_batch


# file_path = upload_doc()

vector_store_id = 'vs_YqhT8wThRGO9ynsFlAipwVxD'

# %%
# You can print the status and the file counts of the batch to see the result of this operation.
print(file_batch.status)
print(file_batch.file_counts)

# %%
# Continuing test function call

client.

assistant = client.beta.assistants.update(
  assistant_id=assistant.id,
  tool_resources={"file_search": {"vector_store_ids": [vector_store_id]}},
)

# Upload the user provided file to OpenAI
message_file = client.files.create(
  file=open("edgar/aapl-10k.pdf", "rb"), purpose="assistants"
)

# Create a thread and attach the file to the message
thread = client.beta.threads.create(
  messages=[
    {
      "role": "user",
      "content": 'What should "" be classified as?',
      # Attach the new file to the message.
      "attachments": [
        { "file_id": message_file.id, "tools": [{"type": "file_search"}] }
      ],
    }
  ]
)

# The thread now has a vector store with that file in its tool resources.
print(thread.tool_resources.file_search)

# %%
# The praser returns dataclasses.
assert len(examples) == 80
assert all(isinstance(x, Example) for x in examples)
assert all(isinstance(e, Entity) for x in examples for e in x.entities)
assert all(isinstance(e, Relation) for x in examples for e in x.relations)
assert all(isinstance(e, Event) for x in examples for e in x.events)

id_ = "BioNLP-ST_2011_EPI/PMID-19377285"
example = next(x for x in examples if x.id == id_)
print(example.text)
print(len(example.entities), next(iter(example.entities)))
print(len(example.relations), next(iter(example.relations)))
print(len(example.events), next(iter(example.events)))

# Use dataclasses.asdict to convert examples to dictionaries.
examples = [*map(dataclasses.asdict, examples)]
assert all(isinstance(x, dict) for x in examples)
assert all(isinstance(e, dict) for x in examples for e in x["entities"])
assert all(isinstance(e, dict) for x in examples for e in x["relations"])
assert all(isinstance(e, dict) for x in examples for e in x["events"])

print(examples[0])
